# %% [markdown]
# ### selenium 라이브러리
# 1. 웹 어플리케이션을 테스트하기 위한 라이브러리
# 2. python에서 웹브라우져를 제어하기 위한 라이브러리
# 3. 크롬의 구버전은 웹드라이버라는 별도의 소프트웨어가 필요

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (4.11.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from selenium) (2.0.4)
# Requirement already satisfied: trio~=0.17 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.1.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# 라이브러리 로드
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
# 웹 브라우저에 주소값을 입력해서 요청
driver.get("https://www.naver.com")

# %%
# HTML TAG들에 접근하기 위한 기능 로드

# By는 TAG들의 속성 값들에 접근하기 위한 기능
from selenium.webdriver.common.by import By

# Keys는 키보드 입력방식에 접근하기 위한 기능
from selenium.webdriver.common.keys import Keys

# %%
# 네이버에 있는 검색창(TAG, element)을 선택
# id가 query인 element를 선택
element = driver.find_element(By.ID, 'query')

# %%
# 검색어창에 특정한 문자열을 입력
element.send_keys('노원맛집')

# %%
# 엔터키를 입력
element.send_keys(Keys.ENTER)

# %%
# class가 Ink_head인 element중 첫번째 element
element2 = driver.find_element(By.CLASS_NAME, 'lnk_head')

# %%
element2.click()

# %%
# 웹브라우져의 탭의 정보를 모두 확인
all_window = driver.window_handles

# %%
# 자식창으로 이동
driver.switch_to.window(all_window[1])

# %%
element3 = driver.find_element(By.CLASS_NAME, 'quick03')

# %%
element3.click()

# %%
# 웹브라우져의 html을 로드
driver.page_source
# Out:
# '<html lang="ko"><head>\n  <meta http-equiv="Content-Type" content="text/html;" charset="UTF-8">\n  <meta name="Author" content="">\n  <meta name="Keywords" content="씨앤피물류, c&amp;p, 씨앤피, 무봉리순대국, 하나샤브샤브, 카페아를, 브래드팩토리, 지베르니, 씨앤피물류, 프랜차이즈, 외식창업, 순대국브랜드, 외식브랜드">\n  <meta name="Description" content="씨앤피물류는 친숙하게 자리잡은 무봉리토종순대국을 시작으로 일식 프리미엄 레스토랑 ‘하나샤브샤브’ 블루리본서베이에 등록된 ‘카페아를’ 자연속의 빵공장 ‘브래드 팩토리’ 등 다양한 외식사업과 전국적인 유통이 가능한 물류센터 를 운영하고 있습니다.">\n  <meta property="og:url" content="">\n  <meta property="og:title" content="씨앤피물류">\n  <meta property="og:site_name" content="씨앤피물류">\n  <meta property="og:image" content="https://cnp-inc.com/common/img/link.jpg">\n  <meta property="og:description" content="씨앤피물류는 친숙하게 자리잡은 무봉리토종순대국을 시작으로 일식 프리미엄 레스토랑 ‘하나샤브샤브’ 블루리본서베이에 등록된 ‘카페아를’ 자연속의 빵공장 ‘브래드 팩토리’ 등 다양한 외식사업과 전국적인 유통이 가능한 물류센터 를 운영하고 있습니다.">\n  <meta property="og:url" content="https://cnp-inc.com">\n  <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no">\n  <meta name="format-detection" content="telephone=no, address=no, email=no">\n  <meta name="google-signin-client_id" content="113572910695-15kca0sj71rbgbb0cg9uk1vr2a7b5ngp.apps.googleusercontent.com">\n  <script type="text/javascript" src="//dapi.kakao.com/v2/maps/sdk.js?appkey=d50aa0309f54304949cfb50d2aabc6f1"></script>\n  <meta name="naver-site-verification" content="764a39a1ac8919ac74658cdd5e52dbf5caab7404">\n  <title>씨앤피물류</title>\n  <!--css-->\n\n    <link rel="stylesheet" type="text/css" href="/common/fonts/NanumBarunGothic/nanumbarungothic.css">\n  <link rel="stylesheet" type="text/css" href="/common/fonts/NanumGothic/css/font-NanumGothic.css">\n  <link rel="stylesheet" type="text/css" href="/common/fonts/NanumSquare/css/font-NanumSquare.css">\n  <link rel="stylesheet" type="text/css" href="/common/fonts/NotoSansKR/css/font-NotoSansKR.css">\n  <link rel="stylesheet" type="text/css" href="/common/fonts/HerrVonMuellerhoff/font.css">\n  <link rel="stylesheet" type="text/css" href="/common/fonts/Montserrat/font.css">\n  <link rel="stylesheet" href="//cdn.jsdelivr.net/npm/xeicon@2/xeicon.min.css">\n  <link rel="stylesheet" type="text/css" href="/common/fonts/Awesome4.7.0/css/font-awesome.css">\n  <link href="https://fonts.googleapis.com/css?family=Open+Sans:300" rel="stylesheet">\n  \t<link rel="stylesheet" href="https://cdn.jsdelivr.net/bxslider/4.2.12/jquery.bxslider.css">\n  <link rel="stylesheet" type="text/css" href="/common/css/css3_menu.css">\n  <link rel="stylesheet" type="text/css" href="/common/css/default.css">\n\n  <!--js-->\n    <script src="/common/js/jquery-1.11.1.min.js"></script>\n\t <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">\n  <script type="text/javascript" src="/common/js/jquery-ui-192.js"></script>\n  <script src="/common/js/jquery.easings.min.js"></script>\n  <script src="/common/js/jquery-migrate-1.2.1.min.js"></script>\n  <script src="/common/js/jquery-ui.min.js"></script>\n  <script src="/common/js/jquery.dotdotdot.js"></script>\n  <script src="/common/js/tweenMax.js"></script>\n  <script src="/common/js/sticky-kit.js"></script>\n  <script src="/common/js/velocity.min.js"></script>\n  <script src="/common/js/jquery.animateNumber.js"></script>\n  <script src="/common/js/skrollr.min.js"></script>  \n  \n  <script src="/common/js/instafeed.min.js"></script>\n  <script src="/common/js/set_insta.js"></script><script id="instafeed-fetcher" src="https://api.instagram.com/v1/users/1265481915/media/recent?access_token=1265481915.b28b44a.9500078628cc466fa200480f0d8e6d63&amp;count=12&amp;callback=instafeedCachea39e418dc172ae46.parse"></script>\n  <script src="/common/plugins/slick/slick.js"></script>\n  <script src="/common/plugins/gray-gh-pages/js/jquery.gray.js"></script>  \n  <script src="https://unpkg.com/masonry-layout@4/dist/masonry.pkgd.min.js"></script>\n  <script src="/common/js/imagesloaded.js"></script>\n  <script src="/common/js/waypoint.min.js"></script>\n  <s ...

# %%
from bs4 import BeautifulSoup as bs

# %%
# driver에 있는 page_source를 BeautifulSoup에서 사용하기 위해 데이터를 변환
soup = bs(driver.page_source, 'html.parser')

# %%
soup
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8" content="text/html;" http-equiv="Content-Type"/>
# <meta content="" name="Author"/>
# <meta content="씨앤피물류, c&amp;p, 씨앤피, 무봉리순대국, 하나샤브샤브, 카페아를, 브래드팩토리, 지베르니, 씨앤피물류, 프랜차이즈, 외식창업, 순대국브랜드, 외식브랜드" name="Keywords"/>
# <meta content="씨앤피물류는 친숙하게 자리잡은 무봉리토종순대국을 시작으로 일식 프리미엄 레스토랑 ‘하나샤브샤브’ 블루리본서베이에 등록된 ‘카페아를’ 자연속의 빵공장 ‘브래드 팩토리’ 등 다양한 외식사업과 전국적인 유통이 가능한 물류센터 를 운영하고 있습니다." name="Description"/>
# <meta content="" property="og:url"/>
# <meta content="씨앤피물류" property="og:title"/>
# <meta content="씨앤피물류" property="og:site_name"/>
# <meta content="https://cnp-inc.com/common/img/link.jpg" property="og:image"/>
# <meta content="씨앤피물류는 친숙하게 자리잡은 무봉리토종순대국을 시작으로 일식 프리미엄 레스토랑 ‘하나샤브샤브’ 블루리본서베이에 등록된 ‘카페아를’ 자연속의 빵공장 ‘브래드 팩토리’ 등 다양한 외식사업과 전국적인 유통이 가능한 물류센터 를 운영하고 있습니다." property="og:description"/>
# <meta content="https://cnp-inc.com" property="og:url"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="telephone=no, address=no, email=no" name="format-detection"/>
# <meta content="113572910695-15kca0sj71rbgbb0cg9uk1vr2a7b5ngp.apps.googleusercontent.com" name="google-signin-client_id"/>
# <script src="//dapi.kakao.com/v2/maps/sdk.js?appkey=d50aa0309f54304949cfb50d2aabc6f1" type="text/javascript"></script>
# <meta content="764a39a1ac8919ac74658cdd5e52dbf5caab7404" name="naver-site-verification"/>
# <title>씨앤피물류</title>
# <!--css-->
# <link href="/common/fonts/NanumBarunGothic/nanumbarungothic.css" rel="stylesheet" type="text/css"/>
# <link href="/common/fonts/NanumGothic/css/font-NanumGothic.css" rel="stylesheet" type="text/css"/>
# <link href="/common/fonts/NanumSquare/css/font-NanumSquare.css" rel="stylesheet" type="text/css"/>
# <link href="/common/fonts/NotoSansKR/css/font-NotoSansKR.css" rel="stylesheet" type="text/css"/>
# <link href="/common/fonts/HerrVonMuellerhoff/font.css" rel="stylesheet" type="text/css"/>
# <link href="/common/fonts/Montserrat/font.css" rel="stylesheet" type="text/css"/>
# <link href="//cdn.jsdelivr.net/npm/xeicon@2/xeicon.min.css" rel="stylesheet"/>
# <link href="/common/fonts/Awesome4.7.0/css/font-awesome.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300" rel="stylesheet"/>
# <link href="https://cdn.jsdelivr.net/bxslider/4.2.12/jquery.bxslider.css" rel="stylesheet"/>
# <link href="/common/css/css3_menu.css" rel="stylesheet" type="text/css"/>
# <link href="/common/css/default.css" rel="stylesheet" type="text/css"/>
# <!--js-->
# <script src="/common/js/jquery-1.11.1.min.js"></script>
# <link href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css" rel="stylesheet"/>
# <script src="/common/js/jquery-ui-192.js" type="text/javascript"></script>
# <script src="/common/js/jquery.easings.min.js"></script>
# <script src="/common/js/jquery-migrate-1.2.1.min.js"></script>
# <script src="/common/js/jquery-ui.min.js"></script>
# <script src="/common/js/jquery.dotdotdot.js"></script>
# <script src="/common/js/tweenMax.js"></script>
# <script src="/common/js/sticky-kit.js"></script>
# <script src="/common/js/velocity.min.js"></script>
# <script src="/common/js/jquery.animateNumber.js"></script>
# <script src="/common/js/skrollr.min.js"></script>
# <script src="/common/js/instafeed.min.js"></script>
# <script src="/common/js/set_insta.js"></script><script id="instafeed-fetcher" src="https://api.instagram.com/v1/users/1265481915/media/recent?access_token=1265481915.b28b44a.9500078628cc466fa200480f0d8e6d63&amp;count=12&amp;callback=instafeedCachea39e418dc172ae46.parse"></script>
# <script src="/common/plugins/slick/slick.js"></script>
# <script src="/common/plugins/gray-gh-pages/js/jquery.gray.js"></script>
# <script src="https://unpkg.com/masonry-layout@4/dist/masonry.pkgd.min.js"></script>
# <script src="/common/js/imagesloaded.js"></script>
# <script src="/common/js/waypoint.min.js"></script>
# <script src="/common/js/jquery.counterup.min.js"></script>
# <script src="/admin/common/js/jquery.form.js"></script>
# <script src="/common/js/script.js"></script>
# <script async="" defer="" gapi_processed="true" src="https://apis.google.com/js/platform.js"></script>
# <script src="https://cdn.jsdelivr.net/bxslider/4.2.12/jquery.bxslider.min.js"></script>
# <!--plugin-->
# </head>
# <body>
# <div id="wrap">
# <!--header s-->
# <style>
# </style>
# <script>
# 	$(document).ready(function(){
# 		$(".big_menu_top > i.xi-close").click(function(e){
# 			e.preventDefault();
# 			$('.big_menu_bg').fadeOut();
# 			$('.big_menu_top').slideUp();
# 			$('.big_menu_bot').slideUp();
# 		});
#
# 		$(".nav-icon1").click(function(e){
# 			e.preventDefault();
# 			$('.big_menu_bg').fadeIn();
# 			$('.big_menu_top').slideDown();
# 			$('.big_menu_bot').slideDown();
# 		});
#
#
#
# 			$(".big_menu_bot > ul.menu2 > li > a").click(function(e){
# 				e.preventDefault();
# 				$(this).parent().find("> ul").slideToggle();
# 				$(this).parent().siblings().find("> ul").slideUp();
# 				$(this).parent().siblings().find("> i.xi-angle-down-thin").removeClass("on");
# 				$(this).parent().find("> i.xi-angle-down-thin").toggleClass("on");
# 			});
#
# 			$(".big_menu_top > i").click(function(e){
# 				e.preventDefault();
# 				$(".big_menu_bot > ul.menu2 > li > ul").slideUp();
# 				$("i.xi-angle-down-thin").removeClass("on");
#
# 			});
#
#
# 	});
#
# </script>
# <div class="big_menu_bg"></div>
# <div class="big_menu_top">
# <ul class="">
# <li><img alt="" src="/common/img/logo.png"/></li>
# </ul>
# <i class="xi-close"></i>
# </div>
# <div class="big_menu_bot">
# <ul class="menu1">
# <li><a href="#">씨앤피소개</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/company/company.html"><strong>기업소개</strong></a></li>
# <li><a href="/contents/company/vision.html"><strong>비전</strong></a></li>
# <li><a href="/contents/company/distribution.html"><strong>물류</strong></a></li>
# <li><a href="/contents/company/ceo.html"><strong>CEO인사말</strong></a></li>
# <li><a href="/contents/company/history.html"><strong>연혁</strong></a></li>
# <li><a href="/contents/company/cibi.html"><strong>CI/BI</strong></a></li>
# <li><a href="/contents/company/contact.html"><strong>오시는길</strong></a></li>
# </ul>
# </li>
# <li><a href="#">브랜드소개</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/brand/franchise.html"><strong>프랜차이즈</strong></a>
# <ul class="">
# <li><a href="/contents/brand/moobongri.html">- 무봉리순대국</a></li>
# <li><a href="/contents/brand/hana.html">- 하나 샤브샤브</a></li>
# </ul>
# </li>
# <li><a href="/contents/brand/direct.html"><strong>직영외식브랜드</strong></a>
# <ul class="">
# <li><a class="ls0" href="/contents/brand/direct.html#anarkh">- Anarkh</a></li>
# <li><a class="ls0" href="/contents/brand/direct.html#giverny">- Giverny</a></li>
# <li><a class="ls0" href="/contents/brand/direct.html#arles">- Cafe Arles</a></li>
# <li><a class="ls0" href="/contents/brand/direct.html#bread">- Bread Factory</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="#">매장안내</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/store/store.html"><strong>매장찾기</strong></a></li>
# </ul>
# </li>
# <li><a href="#">창업안내</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/startup/start_info.html"><strong>브랜드별 창업안내</strong></a></li>
# <li><a href="/contents/startup/start_story.html"><strong>창업스토리</strong></a></li>
# <li><a href="/contents/startup/start_contact.html"><strong>창업문의</strong></a></li>
# </ul>
# </li>
# <li><a href="#">소식</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/board/notice.html"><strong>공지사항</strong></a></li>
# <li><a href="/contents/board/new_media.html"><strong>뉴스&amp;미디어</strong></a></li>
# <li><a href="/contents/board/sns.html"><strong>소셜라이브</strong></a></li>
# <li><a href="/contents/board/event.html"><strong>이벤트</strong></a></li>
# <li><a href="/contents/board/recruit.html"><strong>인재채용</strong></a></li>
# </ul>
# </li>
# <li><a href="#">고객의소리</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/customer/customer.html"><strong>고객의소리</strong></a></li>
# <li><a href="/contents/orner/login.html"><strong>점주공간</strong></a></li>
# </ul>
# </li>
# </ul>
# <ul class="menu2">
# <li><a href="#">씨앤피소개</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/company/company.html">• 기업소개</a></li>
# <li><a href="/contents/company/vision.html">• 비전</a></li>
# <li><a href="/contents/company/distribution.html">• 물류</a></li>
# <li><a href="/contents/company/ceo.html">• CEO인사말</a></li>
# <li><a href="/contents/company/history.html">• 연혁</a></li>
# <li><a href="/contents/company/cibi.html">• CI/BI</a></li>
# <li><a href="/contents/company/contact.html">• 오시는길</a></li>
# </ul>
# </li>
# <li><a href="#">브랜드소개</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/brand/franchise.html">• 프랜차이즈</a>
# <ul class="">
# <li><a href="/contents/brand/moobongri.html">- 무봉리순대국</a></li>
# <li><a href="/contents/brand/hana.html">- 하나 샤브샤브</a></li>
# </ul>
# </li>
# <li><a href="/contents/brand/direct.html">• 직영외식브랜드</a>
# <ul class="">
# <li><a class="ls0" href="/contents/brand/direct.html#anarkh">- Anarkh</a></li>
# <li><a href="/contents/brand/direct.html#giverny">- Giverny</a></li>
# <li><a href="/contents/brand/direct.html#arles">- Cafe Arles</a></li>
# <li><a href="/contents/brand/direct.htm#bread">- Bread Factory</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li><a href="#">매장안내</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/store/store.html">• 매장찾기</a></li>
# </ul>
# </li>
# <li><a href="#">창업안내</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/startup/start_info.html">• 브랜드별 창업안내</a></li>
# <li><a href="/contents/startup/start_story.html">• 창업스토리</a></li>
# <li><a href="/contents/startup/start_contact.html">• 창업문의</a></li>
# </ul>
# </li>
# <li><a href="#">소식</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/board/notice.html">• 공지사항</a></li>
# <li><a href="/contents/board/new_media.html">• 뉴스&amp;미디어</a></li>
# <li><a href="/contents/board/sns.html">• 소셜라이브</a></li>
# <li><a href="/contents/board/event.html">• 이벤트</a></li>
# <li><a href="/contents/board/recruit.html">• 인재채용</a></li>
# </ul>
# </li>
# <li><a href="#">고객의소리</a>
# <i class="xi-angle-down-thin"></i>
# <ul class="">
# <li><a href="/contents/customer/customer.html">• 고객의소리</a></li>
# <li><a href="/contents/orner/login.html">• 점주공간</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <script>
# $(document).ready(function(){
# 	// gnb:s
# 	$('.gnb > li').mouseenter(function(){
# 		$('> a',this).addClass('on');
# 		$('> .gnb2',this).stop(true,true).slideDown(300)
# 		$(this).mouseleave(function(){
# 			$('> a',this).removeClass('on');
# 			$('> .gnb2',this).hide(200)
# 		})
# 	 })
# });
# </script>
# <style>
# .gnb > li{display: inline-block; position: relative; list-style: none;}
# .gnb2{position:absolute; top:100%; left:0; width:150px;  background:#fff; margin-left:-45px; margin-top:-20px; padding:10px 0; box-sizing:border-box; border:1px solid #ddd;  z-index:110; display:none;}
# .gnb2 li{height:20px;; text-align: left;  box-sizing:border-box; text-align:center;}
# .gnb2 li+li{margin-top:4px}
# .gnb2 li a{font-size:14px; color:#333; height:20px; background:url('/common/img/check_bullet_off.png') no-repeat left 5px; transition:all, .5s; display:inline-block;  letter-spacing:-1px}
# .gnb2 li a:hover{color:#00726f; text-decoration:underline !important;}
# /*.gnb2 li a:hover{background:url('/common/img/check_bullet.png') no-repeat left 5px; transition:all, .5s;}*/
# </style>
# <div id="header">
# <div class="head_wrap">
# <div class="center">
# <div class="head_left">
# <a href="/index.html"><img alt="" class="off" src="/common/img/logo.png"/><img alt="" class="on" src="/common/img/logo_2.png"/></a>
# </div>
# <div class="head_center">
# <ul class="gnb">
# <li><a href="/contents/company/company.html">기업소개</a>
# <ul class="gnb2">
# <li><a href="/contents/company/company.html">기업소개</a></li>
# <li><a href="/contents/company/vision.html">비전</a></li>
# <li><a href="/contents/company/distribution.html">물류</a></li>
# <li><a href="/contents/company/ceo.html">CEO인사말</a></li>
# <li><a href="/contents/company/history.html">연혁</a></li>
# <li><a href="/contents/company/cibi.html">CI/BI</a></li>
# <li><a href="/contents/company/contact.html">오시는길</a></li>
# </ul>
# </li>
# <li><a href="/contents/brand/franchise.html">브랜드소개</a>
# <ul class="gnb2">
# <li><a href="/contents/brand/franchise.html">프랜차이즈</a></li>
# <li><a href="/contents/brand/direct.html">직영외식브랜드</a></li>
# </ul>
# </li>
# <li><a href="/contents/store/store.html">매장안내</a>
# <ul class="gnb2">
# <li><a href="/contents/store/store.html">매장찾기</a></li>
# </ul>
# </li>
# <li><a href="/contents/startup/start_info.html">창업안내</a>
# <ul class="gnb2">
# <li><a href="/contents/startup/start_info.html">브랜드별 창업안내</a></li>
# <li><a href="/contents/startup/start_story.html">창업스토리</a></li>
# <li><a href="/contents/startup/start_contact.html">창업문의</a></li>
# </ul>
# </li>
# <li><a href="/contents/board/notice.html">소식</a>
# <ul class="gnb2">
# <li><a href="/contents/board/notice.html">공지사항</a></li>
# <li><a href="/contents/board/new_media.html">뉴스&amp;미디어</a></li>
# <li><a href="/contents/board/sns.html">소셜라이브</a></li>
# <li><a href="/contents/board/event.html">이벤트</a></li>
# <li><a href="/contents/board/recruit.html">인재채용</a></li>
# </ul>
# </li>
# <li><a href="/contents/customer/customer.html">고객의소리</a>
# <ul class="gnb2">
# <li><a href="/contents/customer/customer.html">고객의소리</a></li>
# <li><a href="/contents/orner/login.html">점주공간</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="head_right">
# <ul class="">
# <li><a href="/contents/join/login.html">로그인</a></li>
# <li>·</li>
# <li><a href="/contents/join/join_step1.html">회원가입</a></li>
# <li>
# <div class="nav-icon1">
# <span></span>
# <span></span>
# <span></span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!--header e-->
# <!--container s-->
# <div id="container">
# <!--서브 비쥬얼 및 메뉴-->
# <div class="sub_visual_boss">
# <div class="sub_visual">
# <div class="sub_visual_wrap lcg_table sub_visual_wrap4">
# <span class="bg"></span>
# <div class="lcg_table_cell">
# <p class="title" style="zoom: 1; opacity: 1;">FOUNDATION</p>
# <p class="text" style="zoom: 1; opacity: 0.7;">Franchise Brand Directiong Group</p>
# <span class="line"></span>
# <p class="text1" style="opacity: 0.7; transform: matrix(1, 0, 0, 1, 0, 0);">창업은 부담없이! 매출은 실속있게!  남녀노소 모두가 좋아하는 다양한 메뉴 <br/>
# 씨앤피는 행복을 위한 동행을 약속 드립니다.</p>
# </div>
# </div>
# </div>
# <div class="sub_menu">
# <ul class="sub_menu_list1 sub_menu_list4">
# <li class=""><a href="/contents/startup/start_info.html">브랜드별 창업안내</a></li>
# <li class=""><a href="/contents/startup/start_story.html">창업스토리</a></li>
# <li class="on"><a href="/contents/startup/start_contact.html">창업문의</a></li>
# </ul>
# </div>
# </div>
# <!--서브 비쥬얼 및 메뉴-->
# <!--서브 타이틀-->
# <div class="sub_title_wrap">
# <div class="sub_title">
# <p class="title">NEW STORE</p>
# <p class="text">창업문의</p>
# </div>
# <div class="sub_navi">
# <ul class="">
# <li><i class="xi-home"></i></li>
# <li>메인</li>
# <li><i class="xi-angle-right-min"></i></li>
# <li>창업안내</li>
# <li><i class="xi-angle-right-min"></i></li>
# <li>창업문의</li>
# </ul>
# </div>
# </div>
# <!--서브 타이틀-->
# <!--서브 게시판-->
# <div class="sub_board">
# <div class="customer_wrap">
# <div class="customer_top">
# <div class="check"><input id="check11" name="" type="checkbox"/><label for="check11">개인정보 수집 및 이용에 동의합니다.</label></div>
# <div class="customer_text_wrap">
# <div class="customer_text">
# <style>
# 	.privacy_wrap{font-size:12px;}
# 	.privacy_wrap strong{font-size:14px; }
# </style>
# <div class="privacy_wrap">
# <strong>제1조(목적)</strong> <br/>
# 이 약관은 (주)씨앤피물류 (C&amp;P) 회사(전자거래 사업자)가 운영하는 (주)씨앤피물류 (C&amp;P) 사이버 몰(이하 "몰"이라 한다)에서 제공하는 인터넷 관련 서비스 (이하 "서비스"라 한다)를 이용함에 있어 사이버몰과 이용자의 권리ㆍ의무 및 책임사항을 규정함을 목적으로 합니다. <br/>
# ※ 「PC통신등을 이용하는 전자거래에 대해서도 그 성질에 반하지 않는 한 이 약관을 준용합니다.
#
# <br/><br/><strong>제2조(정의)</strong>
# "몰"이란 (주)씨앤피물류 (C&amp;P) 회사가 재화 또는 용역을 이용자에게 제공하기 위하여 컴퓨터등 정보통신설비를 이용하여 재화 또는 용역을 거래할수 있도록 설정한 가상의 영업장을 말하며, 아울러 사이버몰을 운영하는 사업자의 의미로도 사용합니다.<br/>
# "이용자"란 "몰"에 접속하여 이 약관에 따라 "몰"이 제공하는 서비스를 받는 회원 및 비회원을 말합니다.<br/>
# ‘회원’이라 함은 "몰"에 개인정보를 제공하여 회원등록을 한 자로서, 계속적으로 “몰”이 제공하는 서비스를 이용할 수 잇는 자를 말합니다.<br/>
# ‘비회원’이라 함은 회원에 가입하지 않고 "몰"이 제공하는 서비스를 이용하는 자를 말합니다.
#
# <br/><br/><strong>제3조(약관등의 명시와 설명 및 개정)</strong>
# "몰"은 이 약관의 내용과 상호 및 대표자 성명, 영업소 소재지 주소(소비자의 불만을 처리할 수 있는 곳의 주소를 포함), 전화번호ㆍ모사전송번호ㆍ전자우편주소, 사업자등록번호, 통신판매업신고번호, 개인정보관리책임자등을 이용자가 쉽게 알 수 있도록 "몰"의 초기서비스화면(전면)에 게시합니다. 다만, 약관의 내용은 이용자가 연결화면을 통하여 볼 수 있도록 할 수 있습니다.<br/>
# "몰"은 이용자가 약관에 동의하기에 앞서 약관에 정하여져 있는 내용 중 청약철회ㆍ배송책임ㆍ환불조건 등과 같은 중요한 내용을 이용자가 이해할 수 있도록 별도의 연결화면 또는 팝업화면 등을 제공하여 이용자의 확인을 구하여야 합니다.<br/>
# "몰"은 전자상거래등에서의 소비자보호에 관한 법률, 약관의 규제에 관한 법률, 전자문서 및 전자거래기본법, 전자금융거래법, 전자서명법, 정보통신망 이용촉진 및 정보보호 등에 관한 법률, 방문판매 등에 관한 법률, 소비자보호법 등 관련법을 위배하지 않는 범위에서 이 약관을 개정할 수 있습니다.<br/>
# "몰"이 약관을 개정할 경우에는 적용일자 및 개정사유를 명시하여 현행약관과 함께 몰의 초기화면에 그 적용일자 7일이전부터 적용일자 전일까지 공지합니다. <br/>
# 다만, 이용자에게 불리하게 약관내용을 변경하는 경우에는 최소한 30일 이상의 사전 유예기간을 두고 공지합니다. 이 경우 "몰"은 개정전 내용과 개정후 내용을 명확하게 비교하여 이용자가 알기 쉽도록 표시합니다.<br/>
# "몰"이 약관을 개정할 경우에는 그 개정약관은 그 적용일자 이후에 체결되는 계약에만 적용되고 그 이전에 이미 체결된 계약에 대해서는 개정전의 약관조항이 그대로 적용됩니다. 다만 이미 계약을 체결한 이용자가 개정약관 조항의 적용을 받기를 원하는 뜻을 제3항에 의한 개정약관의 공지기간내에 "몰"에 송신하여 "몰"의 동의를 받은 경우에는 개정약관 조항이 적용됩니다.<br/>
# 이 약관에서 정하지 아니한 사항과 이 약관의 해석에 관하여는 전자상거래등에서의 소비자보호에 관한 법률, 약관의 규제 등에 관한 법률, 공정거래위원회가 정하는 전자상거래 등에서의 소비자보호지침 및 관계법령 또는 상관례에 따릅니다.
#
# <br/><br/><strong>제4조(서비스의 제공 및 변경)</strong>
# "몰"은 다음과 같은 업무를 수행합니다. <br/>
# ① 재화 또는 용역에 대한 정보 제공 및 구매계약의 체결<br/>
# ② 구매계약이 체결된 재화 또는 용역의 배송<br/>
# ③ 기타 "몰"이 정하는 업무<br/>
# "몰"은 재화 또는 용역의 품질 또는 기술적 사양의 변경 등의 경우에는 장차 체결되는 계약에 의해 제공할 재화 또는 용역의 내용을 변경할 수 있습니다.<br/>
# 이 경우에는 변경된 재화 또는 용역의 내용 및 제공일자를 명시하여 현재의 재화 또는 용역의 내용을 게시한 곳에 즉시 공지합니다.<br/>
# "몰"이 제공하기로 이용자와 계약을 체결한 서비스의 내용을 재화 등의 품질 또는 기술적 사양의 변경 등의 사유로 변경할 경우에는 그 사유를 이용자에게 통지 가능한 주소로 즉시 통지합니다.<br/>
# 전항의 경우 "몰"은 이로 인하여 이용자가 입은 손해를 배상합니다. 다만, "몰"이 고의 또는 과실이 없음을 입증하는 경우에는 그러하지 아니합니다.
#
# <br/><br/><strong>제5조(서비스의 중단)</strong>
# 본 상품을 변심 반품할 경우 반송비는 고객님 부담이며, 초기배송료를 포함한 왕복배송료의 해당 금액을 고객님께서 부담하셔야 합니다. <br/>
# "몰"은 컴퓨터 등 정보통신설비의 보수점검ㆍ교체 및 고장, 통신의 두절 등의 사유가 발생한 경우에는 서비스의 제공을 일시적으로중단할 수 있습니다.<br/>
# "몰"은 제1항의 사유로 서비스의 제공이 일시적으로 중단됨으로 인하여 이용자 또는 제3자가 입은 손해에 대하여 배상합니다. <br/>
# 단, "몰"이 고의 또는 과실이 없음을 입증하는 경우에는 그러하지 아니합니다.<br/>
# 사업종목의 전환, 사업의 포기, 업체간의 통합 등의 이유로 서비스를 제공할 수 없게 되는 경우에는 "몰"은 제8조에 정한 방법으로 이용자에게 통지하고 당초 "몰"에서 제시한 조건에 따라 소비자에게 보상합니다. <br/>
# 다만, "몰"이 보상기준 등을 고지하지 아니한 경우에는 "몰"에서 통용되는 통화가치에 상응하는 현물 또는 현금으로 이용자에게 지급합니다.
#
# <br/><br/><strong>제6조(회원가입)</strong>
# 이용자는 "몰"이 정한 가입 양식에 따라 회원정보를 기입한 후 이 약관에 동의한다는 의사표시를 함으로서 회원가입을 신청합니다.<br/>
# "몰"은 제1항과 같이 회원으로 가입할 것을 신청한 이용자 중 다음 각호에 해당하지 않는 한 회원으로 등록합니다. <br/>
# 1. 가입신청자가 이 약관 제7조제3항에 의하여 이전에 회원자격을 상실한 적이 있는 경우, 다만 제7조제3항에 의한 회원자격 상실 후 3년이 경과한 자로서 "몰"의 회원재가입 승낙을 얻은 경우에는 예외로 한다.<br/>
# 2. 등록 내용에 허위, 기재누락, 오기가 있는 경우<br/>
# 3. 기타 회원으로 등록하는 것이 "몰"의 기술상 현저히 지장이 있다고 판단되는 경우<br/>
# 회원가입계약의 성립시기는 "몰"의 승낙이 회원에게 도달한 시점으로 합니다.<br/>
# 회원은 제15조제1항에 의한 등록사항에 변경이 있는 경우, 상당한 기간이내에 몰에 대하여 회원정보수정등의 방법으로 그 변경사항을 알려야 합니다
#
# <br/><br/><strong>제7조(회원 탈퇴 및 자격 상실 등)</strong>
# 회원은 "몰"에 언제든지 탈퇴를 요청할 수 있으며 "몰"은 즉시 회원탈퇴를 처리합니다.<br/>
# 회원이 다음 각호의 사유에 해당하는 경우, "몰"은 회원자격을 제한 및 정지시킬 수 있습니다. <br/>
# 1. 가입 신청시에 허위 내용을 등록한 경우<br/>
# 2. "몰"을 이용하여 구입한 재화등의 대금, 기타 "몰"이용에 관련하여 회원이 부담하는 채무를 기일에 지급하지 않는 경우<br/>
# 3. 다른 사람의 "몰" 이용을 방해하거나 그 정보를 도용하는 등 전자상거래 질서를 위협하는 경우<br/>
# 4. "몰"을 이용하여 법령 또는 이 약관이 금지하거나 공서양속에 반하는 행위를 하는 경우
#
# <br/><br/><strong>제8조(회원에 대한 통지)</strong>
# "몰"이 회원에 대한 통지를 하는 경우, 회원이 "몰"과 미리 약정하여 지정한 전자우편 주소로 할 수 있습니다.<br/>
# "몰"은 불특정다수 회원에 대한 통지의 경우 1주일이상 "몰" 게시판에 게시함으로서 개별 통지에 갈음할 수 있습니다. <br/>
# 다만, 회원 본인의 거래와 관련하여 중대한 영향을 미치는 사항에 대하여는 개별통지를 합니다.
#
# <br/><br/><strong>제9조(구매신청 및 개인정보 제공 동의 등)</strong>
# "몰"이용자는 "몰"상에서 다음 또는 이와 유사한 방법에 의하여 구매를 신청하며, "몰"은 이용자가 구매신청을 함에 있어서 다음의 각 내용을 알기 쉽게 제공하여야 합니다. <br/>
# ① 재화등의 검색 및 선택<br/>
# ② 성명, 주소, 전화번호, 전자우편주소(또는 이동전화번호) 등의 입력<br/>
# ③ 약관내용, 청약철회권이 제한되는 서비스, 배송료ㆍ설치비 등의 비용부담과 관련한 내용에 대한 확인<br/>
# ④ 이 약관에 동의하고 위 3호의 사항을 확인하거나 거부하는 표시(예, 마우스 클릭)<br/>
# ⑤ 재화등의 구매신청 및 이에 관한 확인 또는 "몰"의 확인에 대한 동의<br/>
# ⑥ 결제방법의 선택<br/>
# “몰”이 제3자에게 구매자 개인정보를 제공할 필요가 있는 경우 <br/>
# 1)개인정보를 제공받는 자, <br/>
# 2)개인정보를 제공받는 자의 개인정보 이용목정, <br/>
# 3)제공하는 개인정보의 항목,<br/>
# 4)개인정보를 제공받는 자의 개인정보 보유 및 이용기간을 구매자에게 알리고 동의를 받아야 합니다. <br/>
# (동의를 받은 사항이 변경되는 경우에도 같습니다.)<br/>
#
# ”몰”이 제3자에게 구매자의 개인정보를 취급할 수 있도록 업무를 위탁하는 경우에는 <br/>
# 1)개인정보 취급 위탁을 받은 자, <br/>
# 2) 개인정보 취급위탁을 하는 업무의 내용을 구매자에게 알리고 동의를 받아야 합니다. (동의를 받은 사항이 변경되는 경우에도 같습니다.) <br/>
# 다만, 서비스 제공에 관한 계약이행을 위해 필요하고 구매자의 편의증진과 관련된 경우에는 정보통신망 이용촉진 및 정보보호 등에 관한 법률에서 정하고 있는 방법으로 개인정보 취급방침을 통해 알림으로써 고지절차와 동의 절차를 거치지 않아도 됩니다.
#
# <br/><br/><strong>제10조 (계약의 성립)</strong>
# "몰"은 제9조와 같은 구매신청에 대하여 다음 각호에 해당하면 승낙하지 않을 수 있습니다.<br/>
# 다만, 미성년자와 계약을 체결하는 경우에는 법정 대리인의 동의를 얻지 못하면 미성년자 본인 또는 법정 대리인이 계약을 취소할 수 있다는 애용을 고지하여야 합니다. <br/>
# ① 신청 내용에 허위, 기재누락, 오기가 있는 경우<br/>
# ② 미성년자가 담배, 주류 등 청소년보호법에서 금지하는 재화 및 용역을 구매하는 경우<br/>
# ③ 기타 구매신청에 승낙하는 것이 "몰" 기술상 현저히 지장이 있다고 판단하는 경우<br/>
# "몰"의 승낙이 제12조제1항의 수신확인통지형태로 이용자에게 도달한 시점에 계약이 성립한 것으로 봅니다.<br/>
# "몰"의 승낙의 의사표시에는 이용자의 구매 신청에 대한 확인 및 판매가능 여부, 구매신청의 정정 취소 등에 관한 정보 등을 포함하여야 합니다.
#
# <br/><br/><strong>제11조(지급방법)</strong>
# "몰"에서 구매한 재화 또는 용역에 대한 대금지급방법은 다음 각호의 방법중 가용한 방법으로 할 수 있습니다. <br/>
# 단, "몰"은 이용자의 지급방법에 대하여 재화 등의 대금에 어떠한 명목의 수수료도 추가하여 징수할 수 없습니다. <br/>
# 폰뱅킹, 인터넷뱅킹, 메일 뱅킹 등의 각종 계좌이체<br/>
# 선불카드, 직불카드, 신용카드 등의 각종 카드 결제<br/>
# 온라인 무통장입금<br/>
# 전자화폐에 의한 결제<br/>
# 수령시 대금지급<br/>
# 마일리지 등 “몰”이 지급한 포인트에 의한 결제<br/>
# ”몰”과 계약을 맺었거나 “몰”이 인정한 상품권에 의한 결제<br/>
# 기타 전자적 지급 방법에 의한 대금 지급 등
#
# <br/><br/><strong>제12조(수신확인통지ㆍ구매신청 변경 및 취소)</strong>
# "몰"은 이용자의 구매신청이 있는 경우 이용자에게 수신확인통지를 합니다.<br/>
# 수신확인통지를 받은 이용자는 의사표시의 불일치등이 있는 경우에는 수신확인통지를 받은 후 즉시 구매신청 변경 및 취소를 요청할 수 있고"몰"은 배송전에 이용자의 요청이 있는 경우에는 지체없이 그 요청에 따라 처리하여야 합니다. 다만 이미 대금을 지불한 경우에는 제15조의 청약철회 등에 관한 규정에 따릅니다.
#
# <br/><br/><strong>제13조(재화 등의 공급)</strong>
# "몰"은 이용자와 재화 등의 공급시기에 관하여 별도의 공지가 없는 이상, 이용자가 청약을 한 날부터 7일 이내에 재화 등을 배송할 수 있도록 주문제작, 포장 등 기타의 필요한 조치를 취합니다.<br/>
# 다만, “몰”이 이미 재화 등의 대금의 전부 또는 일부를 받지 않은 경우에는 대금의 전부 또는 일부를 받은 날부터3영업일 이내에 조치를 취합니다.<br/>
# 이때 “몰”은 이용자가 재화 등의 공급 절차 및 진행 사항을 확인할 수 있도록 적절한 조치를 합니다.<br/>
# "몰"은 이용자가 구매한 재화에 대해 배송수단, 수단별 배송비용 부담자, 수단별 배송기간 등을 명시합니다.<br/>
# 만약 "몰"이 약정 배송기간을 초과한 경우에는 그로 인한 이용자의 손해를 배상하여야 합니다. 다만 "몰"이 고의ㆍ과실이 없음을 입증한 경우에는 그러하지 아니합니다.
#
# <br/><br/><strong>제14조(환급)</strong>
# "몰"은 이용자가 구매 신청한 재화 등이 품절 등의 사유로 인도 또는 제공을 할 수 없을 때에는 지체 없이 그 사유를 이용자에게 통지하고 사전에 재화 등의 대금을 받은 경우에는 대금을 받은 날부터 영업일 기준 3일 이내에 환급하거나 환급에 필요한 조치를 취합니다.
#
# <br/><br/><strong>제15조(청약철회 등)</strong>
# "몰"과 재화등의 구매에 관한 계약을 체결한 이용자는「전자상거래 등에서의 소비자보호에 관한 법률」 제 13조 제2항에 따른 계약 내용에 관한 서면을 받은날(그 서면을 받은 때보다 재화 등의 공급이 늦게 이루어진 경우에는 재화 등을 공급하거나 재화 등의 공급이 시작된 날을 말합니다)부터 7일 이내에는 청약의 철회를 할 수 있습니다. <br/>
# 다만, 청약철회에 관하여 「전자상거래 등에서의 소비자보호에 관한 법률」에 달리 정함이 있는 경우에는 동 법 규정에 따릅니다.<br/>
# 이용자는 재화등을 배송 받은 경우 다음 각호의 1에 해당하는 경우에는 반품 및 교환을 할 수 없습니다. <br/>
# ① 이용자에게 책임 있는 사유로 재화 등이 멸실 또는 훼손된 경우(다만, 재화 등의 내용을 확인하기 위하여 포장 등을 훼손한 경우에는 청약철회를 할 수 있습니다.)<br/>
# ② 이용자의 사용 또는 일부 소비에 의하여 재화 등의 가치가 현저히 감소한 경우<br/>
# ③ 시간의 경과에 의하여 재판매가 곤란할 정도로 재화 등의 가치가 현저히 감소한 경우<br/>
# ④ 구매자의 단순 변심에 의한 경우<br/>
# ⑤ 구매자가 제품구매 사전확인 동의서에 동의함을 원칙으로 하며, 그 원칙에 반하는 경우<br/>
# 제2항제2호 내지 제4호의 경우에 “몰”이 사전에 청약철회 등이 제한되는 사실을 소비자가 쉽게 알 수 있는 곳에 명기하거나 사용상품을 제공하는 등의 조치를 하지 않았다면 이용자의 청약철회 등이 제한되지 않습니다.<br/>
# 이용자는 제1항 및 제2항의 규정에 불구하고 재화등의 내용이 표시ㆍ광고 내용과 다르거나 계약내용과 다르게 이행된 때에는 당해 재화 등을 공급받은 날부터 3일이내, 그 사실을 안 날 또는 알 수 있었던 날부터 30일 이내에 청약철회 등을 할 수 있습니다.
#
# <br/><br/><strong>제16조(청약철회 등의 효과)</strong>
# "몰"은 이용자로부터 재화 등을 반환받은 경우 영업일 기준 3일 이내에 이미 지급받은 재화등의 대금을 환급합니다.<br/>
# 이 경우 "몰"이 이용자에게 재화등의 환급을 지연한 때에는 그 지연기간에 대하여「전자상거래 등에서의 소비자보호에 관한 법률 시행령」 제21조2에서 정하는 자연이자율을 곱하여 산정한 지연이자를 지급합니다.<br/>
# "몰"은 위 대금을 환급함에 있어서 이용자가 신용카드 또는 전자화폐 등의 결제수단으로 재화등의 대금을 지급한 때에는 지체없이 당해 결제수단을 제공한 사업자로 하여금 재화등의 대금의 청구를 정지 또는 취소하도록 요청합니다.<br/>
# 청약철회등의 경우 공급받은 재화등의 반환에 필요한 비용은 이용자가 부담합니다. "몰"은 이용자에게 청약철회등을 이유로 위약금 또는 손해배상을 청구하지 않습니다. <br/>
# 다만 재화 등의 내용이 표시ㆍ광고 내용과 다르거나 계약내용과 다르게 이행되어 청약철회 등을 하는 경우 재화등의 반환에 필요한 비용은 "몰"이 부담합니다.<br/>
# 이용자가 재화등을 제공받을때 배송비를 부담한 경우에 "몰"은 청약철회시 그 비용을 누가 부담하는지를 이용자가 알기 쉽도록 명확하게 표시합니다.
#
# <br/><br/><strong>제17조(개인정보보호)</strong>
# "몰"은 이용자의 정보수집시 구매계약 이행에 필요한 최소한의 정보를 수집합니다. 다음 사항을 필수사항으로 하며 그 외 사항은 선택사항으로 합니다. <br/>
#
# ① 성명<br/>
# ② 희망ID(회원의 경우)<br/>
# ③ 비밀번호(회원의 경우)<br/>
# ④ 전자우편주소<br/>
#
#
# "몰"이 이용자의 개인식별이 가능한 개인정보를 수집하는 때에는 반드시 당해 이용자의 동의를 받습니다.<br/>
# “몰”은 회원가입시 구매계약이행에 필요한 정보를 미리 수집하지 않습니다.<br/>
# 다만, 관련 법령상 의무 이행을 위하여 구매계약 이전에 본인확인이 필요한 경우로서 최소한의 특정 개인정보를 수집하는 경우에는 그러하지 아니합니다.<br/>
# 제공된 개인정보는 당해 이용자의 동의없이 목적외의 이용이나 제3자에게 제공할 수 없으며, 새로운 이용목적이 발생한 경우 또는 제3자에게 제공하는 경우에는 이용 제공단계에서 당해 이용자에게 그 목적을 고지하고 동의를 받습니다. 다만, 관련 법령에 달리 정함이 있는 경우에는 예외로 합니다. 다만, 다음의 경우에는 예외로 합니다. <br/>
# ① 배송업무상 배송업체에게 배송에 필요한 최소한의 이용자의 정보(성명, 주소, 전화번호)를 알려주는 경우<br/>
# ② 통계작성, 학술연구 또는 시장조사를 위하여 필요한 경우로서 특정 개인을 식별할 수 없는 형태로 제공하는 경우<br/>
# ③ 재화등의 거래에 따른 대금정산을 위하여 필요한 경우<br/>
# ④ 도용방지를 위하여 본인확인에 필요한 경우<br/>
# ⑤ 법률의 규정 또는 법률에 의하여 필요한 불가피한 사유가 있는 경우<br/>
# "몰"이 제2항과 제3항에 의해 이용자의 동의를 받아야 하는 경우에는 개인정보관리 책임자의 신원(소속, 성명 및 전화번호,기타 연락처), 정보의 수집목적 및 이용목적, 제3자에 대한 정보제공 관련사항(제공받은자, 제공목적 및 제공할 정보의 내용) 등 정보통신망 이용촉진등에 관한 법률 제22조제2항이 규정한 사항을 미리 명시하거나 고지해야 하며 이용자는 언제든지 이 동의를 철회할 수 있습니다.<br/>
# 이용자는 언제든지 "몰"이 가지고 있는 자신의 개인정보에 대해 열람 및 오류정정을 요구할 수 있으며 "몰"은 이에 대해 지체없이 필요한 조치를 취할 의무를 집니다. 이용자가 오류의 정정을 요구한 경우에는 "몰"은 그 오류를 정정할 때까지 당해 개인정보를 이용하지 않습니다.<br/>
# "몰"은 개인정보 보호를 위하여 이용자의 개인정보를 취급하는 자를 최소한으로 제한하여야 하며 신용카드, 은행계좌 등을 포함한 이용자의 개인정보의 분실, 도난, 유출, 변조 등으로 인한 이용자의 손해에 대하여 모든 책임을 집니다.<br/>
# "몰" 또는 그로부터 개인정보를 제공받은 제3자는 개인정보의 수집목적 또는 제공받은 목적을 달성한 때에는 당해 개인정보를 지체없이 파기합니다.<br/>
# ”몰”은 개인정보의 수집 이용 제공에 관한 동의 란을 미리 선택한 것으로 설정해두지 않습니다.<br/>
# 또한 개인정보의 수집 이용 제공에 관한 이용자의 동의거절 시 제한되는 서비스를 구체적으로 명시하고, 필수수집항목이 아닌 개인정보의 수집 이용 제공에 관한 이용자의 동의 거절을 이유로 회원가입 등 서비스 제공을 제한하거나 거절하지 않습니다.<br/>
# <br/><br/><strong>제18조("몰"의 의무)</strong>
# "몰"은 법령과 이 약관이 금지하거나 공서양속에 반하는 행위를 하지 않으며 이 약관이 정하는 바에 따라 지속적이고안정적으로 재화ㆍ용역을 제공하는데 최선을 다하여야 합니다.<br/>
# "몰"은 이용자가 안전하게 인터넷 서비스를 이용할 수 있도록 이용자의 개인정보(신용정보 포함)보호를 위한 보안 시스템을 갖추어야 합니다.<br/>
# "몰"이 상품이나 용역에 대하여 「표시ㆍ광고의 공정화에 관한 법률」 제3조 소정의 부당한 표시ㆍ광고행위를 함으로써 이용자가 손해를 입은 때에는 이를 배상할 책임을 집니다.<br/>
# "몰"은 이용자가 원하지 않는 영리목적의 광고성 전자우편을 발송하지 않습니다.<br/>
# <br/><br/><strong>제19조(회원의 ID 및 비밀번호에 대한 의무)</strong>
# 제17조의 경우를 제외한 ID와 비밀번호에 관한 관리책임은 회원에게 있습니다.<br/>
# 회원은 자신의 ID 및 비밀번호를 제3자에게 이용하게 해서는 안됩니다.<br/>
# 회원이 자신의 ID 및 비밀번호를 도난당하거나 제3자가 사용하고 있음을 인지한 경우에는 바로 "몰"에 통보하고 "몰"의 안내가 있는 경우에는 그에 따라야 합니다.
#
# <br/><br/><strong>제20조(이용자의 의무)</strong>
# 이용자는 다음 행위를 하여서는 안됩니다.<br/>
# 신청 또는 변경시 허위 내용의 등록<br/>
# 타인의 정보 도용<br/>
# "몰"에 게시된 정보의 변경<br/>
# "몰"이 정한 정보 이외의 정보(컴퓨터 프로그램 등) 등의 송신 또는 게시<br/>
# "몰" 기타 제3자의 저작권 등 지적재산권에 대한 침해<br/>
# "몰" 기타 제3자의 명예를 손상시키거나 업무를 방해하는 행위<br/>
# 외설 또는 폭력적인 메시지, 화상, 음성, 기타 공공의 질서와 선량한 풍속에 반하는 행위에 반하는 정보를 몰에 공개 또는 게시하는 행위
#
# <br/><br/><strong>제21조(연결“몰”과 피연결“몰” 간의 관계)</strong>
# 상위 “몰”과 하위 “몰”이 하이퍼링크(예: 하이퍼링크의 대상에는 문자, 그림 및 동화상 등이 포함됨)방식 등으로 연결된 경우,전자를 연결 “몰”(웹 사이트)이라고 하고 후자를 피연결 “몰”(웹사이트)이라고 합니다.<br/>
# 연결“몰”은 피연결“몰”이 독자적으로 제공하는 재화 등에 의하여 이용자와 행하는 거래에 대해서 보증 책임을 지지 않는다는 뜻을 연결 “몰”의 초기화면 또는 연결되는 시점의 팝업화면으로 명시한 경우에는 그 거래에 대한 보증 책임을 지지 않습니다.
#
# <br/><br/><strong>제22조(저작권의 귀속 및 이용제한)</strong>
# "몰"이 작성한 저작물에 대한 저작권 기타 지적재산권은 "몰"에 귀속합니다.<br/>
# 이용자는 "몰"을 이용함으로써 얻은 정보 중 "몰"에게 지적재산권이 귀속된 정보를 "몰"의 사전 승낙없이 복제, 송신, 출판, 배포, 방송 기타 방법에 의하여 영리목적으로 이용하거나 제3자에게 이용하게 하여서는 안됩니다.<br/>
# "몰"은 약정에 따라 이용자에게 귀속된 저작권을 사용하는 경우 당해 이용자에게 통보하여야 합니다.<br/>
# <br/><br/><strong>제23조(분쟁해결)</strong>
# "몰"은 이용자가 제기하는 정당한 의견이나 불만을 반영하고 그 피해를 보상처리하기 위하여 피해보상처리기구를 설치ㆍ운영합니다.<br/>
# "몰"은 이용자로부터 제출되는 불만사항 및 의견은 우선적으로 그 사항을 처리합니다. 다만, 신속한 처리가 곤란한 경우에는 이용자에게 그 사유와 처리일정을 즉시 통보해 드립니다.<br/>
# "몰"과 이용자간에 발생한 전자상거래 분쟁과 관련하여 이용자의 피해구제신청이 있는 경우에는 공정거래위원회 또는 시ㆍ도지사가 의뢰하는 분쟁조정기관의 조정에 따를 수 있습니다.<br/>
# 제24조(재판권 및 준거법)
# "몰"과 이용자간에 발생한 전자상거래 분쟁에 관한 소송은 제소 당시의 이용자의 주소에 의하고, 주소가 없는 경우에는 거소를 관할하는 지방법원의 전속관할로 합니다. 다만, 제소 당시 이용자의 주소 또는 거소가 분명하지 않거나 외국 거주자의 경우에는 민사소송법 상의 관할법원에 제기합니다.<br/>
# "몰"과 이용자간에 제기된 전자상거래 소송에는 한국법을 적용합니다.<br/>
# </div> </div>
# </div>
# </div>
# <div class="customer_bot">
# <p class="check_bullet">필수항목</p>
# <div class="cb"></div>
# <div class="customer_checklist">
# <div class="title">
# 								씨앤피는 여러분과 함께 21세기 꿈과 희망을 열어갑니다.
# 							</div>
# <form action="" enctype="multipart/form-data" id="contactForm" method="POST" name="contactForm">
# <div class="text">
# <table cellpadding="0" cellspacing="0" class="" summary="">
# <colgroup>
# <col width="10%"/><col width="*"/>
# </colgroup>
# <tbody>
# <tr class="m_tr">
# <td></td>
# <td>이름</td>
# </tr>
# <tr class="trname">
# <td>이름</td>
# <td><input class="" id="name" name="name" title="" type="text" value=""/></td>
# </tr>
# <tr class="m_tr">
# <td></td>
# <td>연락처</td>
# </tr>
# <tr class="trphone">
# <td>연락처</td>
# <td>
# <select id="hp01" name="hp01" title="">
# <option selected="selected" value="010">010</option>
# <option value="016">016</option>
# <option value="017">017</option>
# <option value="018">018</option>
# <option value="019">019</option>
# <option value="011">011</option>
# </select>
# <input class="" id="hp02" name="hp02" title="" type="text" value=""/>
# <input class="" id="hp03" name="hp03" title="" type="text" value=""/>
# </td>
# </tr>
# <tr class="m_tr">
# <td></td>
# <td>희망지역</td>
# </tr>
# <tr class="trname">
# <td>희망지역</td>
# <td><input class="" id="area01" name="area01" title="" type="text" value=""/></td>
# </tr>
# <tr class="m_tr">
# <td></td>
# <td>희망브랜드</td>
# </tr>
# <tr class="trphone">
# <td>희망브랜드</td>
# <td>
# <select id="brand" name="brand" title="">
# <option selected="selected" value="">브랜드 선택</option>
# <option value="무봉리순대국">무봉리순대국</option>
# <option value="하나샤브샤브">하나샤브샤브</option>
# <option value="카페아를">카페아를</option>
# <option value="브래드팩토리">브래드팩토리</option>
# <option value="지베르니">지베르니</option>
# </select>
# </td>
# </tr>
# <tr class="m_tr">
# <td></td>
# <td>문의내용</td>
# </tr>
# <tr class="trtext">
# <td>문의내용</td>
# <td><textarea cols="" id="content" name="content" rows="" title=""></textarea></td>
# </tr>
# <tr class="m_tr">
# <td></td>
# <td style="padding:0; background:none;">파일첨부</td>
# </tr>
# <tr class="trfile">
# <td></td>
# <td>
# <input class="" id="fileText" name="fileText" placeholder="첨부파일은 JPG, PNG파일만 가능" readonly="" title="" type="text" value=""/>
# <a class="cp" onclick="javascript: fileClickFunc()">파일찾기</a>
# <input id="image01" name="image01" onchange="javascript: fileChangeFunc(this.value)" style="display:none;" type="file"/>
# </td>
# </tr>
# <tr class="m_tr">
# <td></td>
# <td>보안번호</td>
# </tr>
# <tr class="id">
# <td>보안번호</td>
# <td>
# <input class="" id="secretNum" name="secretNum" placeholder="보안번호 입력" title="" type="text" value=""/>
# <span>31871</span>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </form>
# </div>
# <ul class="join_step3_ul4">
# <li><a class="cp" onclick="javascript: contactWriteFunc()">확인</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!--서브	게시판-->
# <script>
# function fileClickFunc(){
# 	$("#image01").click();
# }
# function fileChangeFunc(n){
#
# 	var fileName = n.slice(n.indexOf(".") + 1).toLowerCase();
# 	if(fileName != "jpg" && fileName != "png" &&  fileName != "gif" &&  fileName != "bmp"){
# 		alert("이미지 파일은 (jpg, png, gif, bmp) 형식만 등록 가능합니다.");
# 		$('#fileText').val("");
# 		$("#image01").val("");
# 	}else{
# 			$('#fileText').val(n);
#
# 	}
# }
# </script>
# </div>
# <!--container e-->
# <!--footer s-->
# <div id="footer">
# <div class="top">
# <div class="top_wrap">
# <div class="top_left">
# <ul class="">
# <li><a href="/contents/company/company.html">COMPANY</a></li>
# <li><span class="line"></span></li>
# <li><a href="/contents/term.html">이용약관</a></li>
# <li><span class="line"></span></li>
# <li><a href="/contents/pri.html">개인정보처리방침</a></li>
# <li><span class="line"></span></li>
# <li><a href="/contents/store/store.html">매장안내</a></li>
# <li><span class="line"></span></li>
# <li><a href="/contents/orner/login.html">점주공간</a></li>
# </ul>
# </div>
# <div class="top_right">
# <ul class="">
# <li><a href="https://blog.naver.com/moobongri1" target="_blank"><img alt="" src="/common/img/fotssns.png"/></a></li>
# <!-- <li><a href="#"><i class="xi-facebook"></i></a></li>
# 							<li><a href="#"><i class="xi-kakaostory"></i></a></li> -->
# <li><a href="https://www.instagram.com/moobongri_official/" target="_blank"><i class="xi-instagram"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="bot">
# <div class="bot_wrap">
# <div class="bot_left">
# <ul class="bot_left_list">
# <li>
# <img alt="" src="/common/img/fotlogo.png"/>
# </li>
# <li>
# <ul class="bot_text">
# <li><span>상호명 : (주)씨앤피물류</span><span>대표 : 김현수 <br class="br_m"/></span></li>
# <li><span>주소 : 경기도 의정부시 민락동 902-4 보광프라자 5층</span></li>
# <li><span>사업자등록번호 : 474-81-00554</span></li>
# <li></li>
# </ul>
# <p>본 사이트의 상품 이미지 및 저작물과 상표 등의 무단 도용 복제 시에는 사전 고지 없이 법적 조치될 수 있습니다.</p>
# </li>
# </ul>
# </div>
# <div class="bot_right">
# <ul class="bot_right_list">
# <li><span>고객지원</span></li>
# <li><a href="tel:1899-6413"><span class="phone">1899-6413</span></a></li>
# <li><span class="date">평일 09:00 ~ 17:00 (주말/공휴일 제외)</span></li>
# <li>
# <ul class="">
# <li><a href="/contents/store/store.html">매장찾기</a></li>
# <li><span class="line"></span></li>
# <li><a href="/contents/startup/start_contact.html">창업문의</a></li>
# <li></li>
# </ul>
# </li>
# </ul>
# <span>Copyright © 2018 C&amp;P Co., Ltd. All right reserved.</span>
# </div>
# </div>
# </div>
# </div>
# <article id="quick">
# <ul>
# <li class="quick01">
# <a href="/contents/board/sns.html"><img alt="" src="/common/img/quick_icon01.png"/></a>
# <p class="info letter"></p>
# </li>
# <li class="quick02">
# <a href="/contents/customer/customer.html"><img alt="" src="/common/img/quick_icon02.png"/></a>
# <!-- <p class="info">고객의 소리</p> -->
# <p class="info letter"></p>
# </li>
# <li class="quick03">
# <a href="/contents/startup/start_contact.html"><img alt="" src="/common/img/quick_icon03.png"/></a>
# <p class="info letter"></p>
# </li>
# </ul>
# </article>
# <style>
# 			#quick{position:fixed;top:20%;right:55px;z-index:10000}
# 			#quick ul{}
# 			#quick ul li{position:relative;display:block;width:40px;height:40px;margin-bottom:10px}
# 			#quick ul li.quick01 .info{width:24px;background:url('/common/img/1a.png') left top no-repeat;     height:100%; padding:0 69px 0 10px; }
# 			#quick ul li.quick02 .info{    width: 40px;  padding: 0; background:url('/common/img/3a.png') left top no-repeat;  text-align:center; padding:0 52px 0 10px;       height:100%;}
# 			#quick ul li.quick03 .info span{color:#f0032b; font-size:12px;}
# 			#quick ul li.quick03 .info{    width: 40px;   padding: 0; background:url('/common/img/2a.png') left top no-repeat;   text-align:center;  padding:0 113px 0 10px;    height:100%; display:block !important;}
# 			#quick ul li a{display:block;}
# 			#quick ul li:hover .info{display:block}
# 			#quick .info{position:absolute;top:50%;right:44px;margin-top:-14px;color:#666;line-height:28px;padding:0 69px 0 10px; display:none;}
# 			@media(max-width:450px){
# 			#quick{display:none;}
# 			}
# 		</style>
# <div class="scroll_top" style="display: block;"><i class="xi-arrow-top xi-x"></i></div>
# <script>
# 			var scroll_header = 0
# 			$(window).scroll(function(){
# 				if($(window).scrollTop() > 50){
# 					if(scroll_header == 1) return;
# 					scroll_header=1
# 					$(".scroll_top").stop().fadeIn(300)
# 				}else{
# 					scroll_header=0
# 					$(".scroll_top").stop().fadeOut(150)
# 				}
# 			})
# 			$(".scroll_top").click(function(){
# 				$("html, body").stop().animate({scrollTop:0},300)
# 				return false;
# 			})
# 		</script>
# <script>
# 			$(document).ready(function(){
# 				$('.top_right > ul > li:eq(0) > a').mouseover(function(){
# 					$(this).find('img').attr('src','/common/img/fotssnson.png');
# 				});
# 				$('.top_right > ul > li:eq(0) > a').mouseleave(function(){
# 					$(this).find('img').attr('src','/common/img/fotssns.png');
# 				});
# 			});
# 		</script> <!--footer e-->
# <script>
# function emailChangeFunc(n){
# 	$("#email02").val(n);
# }
# function contactWriteFunc(){
# 	if($("#check11").is(":checked")==false){
# 		alert("개인정보 수집이용에 동의 하셔야합니다.")
# 		$("#check11").focus();
# 	}else if($("#name").val()==""){
# 		alert("이름을 입력하셔야 합니다.")
# 		$("#name").focus();
# 	}else if($("#hp01").val()==""){
# 		alert("휴대폰번호 첫번째를 선택하셔야 합니다.")
# 		$("#hp01").focus();
# 	}else if($("#hp02").val()==""){
# 		alert("휴대폰번호 두번째를 입력하셔야 합니다.")
# 		$("#hp02").focus();
# 	}else if($("#hp03").val()==""){
# 		alert("휴대폰번호 세번째를 입력하셔야 합니다.")
# 		$("#hp03").focus();
# 	}else if($("#area01").val()==""){
# 		alert("희망지역을 입력하셔야 합니다.")
# 		$("#area01").focus();
# 	}else if($("#brand").val()==""){
# 		alert("브랜드를 선택하셔야 합니다.")
# 		$("#brand").focus();
# 	}else if($("#content").val()==""){
# 		alert("내용을 입력하셔야 합니다.")
# 		$("#content").focus();
# 	}else if($("#secretNum").val()==""){
# 		alert("보안번호를 입력하셔야 합니다.")
# 		$("#secretNum").focus();
# 	}else{
# 		var contactForm = document.getElementById("contactForm");
# 		contactForm.action="/contents/startup/menu4_3_action.php";
# 		contactForm.submit();
# 	}
# }
# </script>
# </div>
# </body></html>

# %%
privacy_data = soup.find('div', 
          attrs={
              'class' : 'privacy_wrap'
          }
).get_text()

# %%
type(privacy_data)
# Out:
# str

# %%
privacy_data = privacy_data.replace('\n', '')
# Out:
# '제1조(목적) 이 약관은 (주)씨앤피물류 (C&P) 회사(전자거래 사업자)가 운영하는 (주)씨앤피물류 (C&P) 사이버 몰(이하 "몰"이라 한다)에서 제공하는 인터넷 관련 서비스 (이하 "서비스"라 한다)를 이용함에 있어 사이버몰과 이용자의 권리ㆍ의무 및 책임사항을 규정함을 목적으로 합니다. ※ 「PC통신등을 이용하는 전자거래에 대해서도 그 성질에 반하지 않는 한 이 약관을 준용합니다. 제2조(정의)"몰"이란 (주)씨앤피물류 (C&P) 회사가 재화 또는 용역을 이용자에게 제공하기 위하여 컴퓨터등 정보통신설비를 이용하여 재화 또는 용역을 거래할수 있도록 설정한 가상의 영업장을 말하며, 아울러 사이버몰을 운영하는 사업자의 의미로도 사용합니다."이용자"란 "몰"에 접속하여 이 약관에 따라 "몰"이 제공하는 서비스를 받는 회원 및 비회원을 말합니다.‘회원’이라 함은 "몰"에 개인정보를 제공하여 회원등록을 한 자로서, 계속적으로 “몰”이 제공하는 서비스를 이용할 수 잇는 자를 말합니다.‘비회원’이라 함은 회원에 가입하지 않고 "몰"이 제공하는 서비스를 이용하는 자를 말합니다.제3조(약관등의 명시와 설명 및 개정)"몰"은 이 약관의 내용과 상호 및 대표자 성명, 영업소 소재지 주소(소비자의 불만을 처리할 수 있는 곳의 주소를 포함), 전화번호ㆍ모사전송번호ㆍ전자우편주소, 사업자등록번호, 통신판매업신고번호, 개인정보관리책임자등을 이용자가 쉽게 알 수 있도록 "몰"의 초기서비스화면(전면)에 게시합니다. 다만, 약관의 내용은 이용자가 연결화면을 통하여 볼 수 있도록 할 수 있습니다."몰"은 이용자가 약관에 동의하기에 앞서 약관에 정하여져 있는 내용 중 청약철회ㆍ배송책임ㆍ환불조건 등과 같은 중요한 내용을 이용자가 이해할 수 있도록 별도의 연결화면 또는 팝업화면 등을 제공하여 이용자의 확인을 구하여야 합니다."몰"은 전자상거래등에서의 소비자보호에 관한 법률, 약관의 규제에 관한 법률, 전자문서 및 전자거래기본법, 전자금융거래법, 전자서명법, 정보통신망 이용촉진 및 정보보호 등에 관한 법률, 방문판매 등에 관한 법률, 소비자보호법 등 관련법을 위배하지 않는 범위에서 이 약관을 개정할 수 있습니다."몰"이 약관을 개정할 경우에는 적용일자 및 개정사유를 명시하여 현행약관과 함께 몰의 초기화면에 그 적용일자 7일이전부터 적용일자 전일까지 공지합니다. 다만, 이용자에게 불리하게 약관내용을 변경하는 경우에는 최소한 30일 이상의 사전 유예기간을 두고 공지합니다. 이 경우 "몰"은 개정전 내용과 개정후 내용을 명확하게 비교하여 이용자가 알기 쉽도록 표시합니다."몰"이 약관을 개정할 경우에는 그 개정약관은 그 적용일자 이후에 체결되는 계약에만 적용되고 그 이전에 이미 체결된 계약에 대해서는 개정전의 약관조항이 그대로 적용됩니다. 다만 이미 계약을 체결한 이용자가 개정약관 조항의 적용을 받기를 원하는 뜻을 제3항에 의한 개정약관의 공지기간내에 "몰"에 송신하여 "몰"의 동의를 받은 경우에는 개정약관 조항이 적용됩니다.이 약관에서 정하지 아니한 사항과 이 약관의 해석에 관하여는 전자상거래등에서의 소비자보호에 관한 법률, 약관의 규제 등에 관한 법률, 공정거래위원회가 정하는 전자상거래 등에서의 소비자보호지침 및 관계법령 또는 상관례에 따릅니다.제4조(서비스의 제공 및 변경)"몰"은 다음과 같은 업무를 수행합니다. ① 재화 또는 용역에 대한 정보 제공 및 구매계약의 체결② 구매계약이 체결된 재화 또는 용역의 배송③ 기타 "몰"이 정하는 업무"몰"은 재화 또는 용역의 품질 또는 기술적 사양의 변경 등의 경우에는 장차 체결되는 계약에 의해 제공할 재화 또는 용역의 내용을 변경할 수 있습니다.이 경우에는 변경된 재화 또는 용역의 내용 및 제공일자를 명시하여 현재의 재화 또는 용역의 내용을 게시한 곳에 즉시 공지합니다."몰"이 제공하기로 이용자와 계약을 체결한 서비스의 내용을 재화 등의 품질 또는 기술적 사양의 변경 등의 사유로 변경할 경우에는 그 사유를 이용자에게 통지 가능한 주소로 즉시 통지합니다.전항의 경우 "몰"은 이로 인하여 이용자가 입은 손해를 배상합니다. 다만, "몰"이 고의 또는 과실이 없음을 입증하는 경우에는 그러하지 아니합니다.제5조(서비스의 중단)본 상품을 변심 반품할 경우 반송비는 고객님 부담이며, 초기배송료를 포함한 왕복배송료의 해당 금액을 고객님께서 부담하셔야 합니다. "몰"은 컴퓨터 등 정보통신설비의 보수점검ㆍ교체 및 고장, 통신의 두절 등의 사유가 발생한 경우에는 서비스의 제공을 일시적으로중단할 수 있습니다."몰"은 제1항의 사유로 서비스의 제공이 일시적으로 중단됨으로 인하여 이용자 또는 제3자가 입은 손해에 대하여 배상합니다. 단, "몰"이 고의 또는 과실이 없음을 입증하는 경우에는 그러하지 아니합니다.사업종목의 전환, 사업의 포기, 업체간의 통합 등의 이유로 서비스를 제공할 수 없게 되는 경우에는 "몰"은 제8조에 정한 방법으로 이용자에게 통지하고 당초 "몰"에서 제시한 조건에 따라 소비자에게 보상합니다. 다만, "몰"이 보상기준 등을 고지하지 아니한 경우에는 "몰"에서 통용되는 통화가치에 상응하는 현물 또는 현금으로 이용자에게 지급합니다.제6조(회원가입)이용자는 "몰"이 정한 가입 양식에 따라 회원정보를 기입한 후 이 약관에 동의한다는 의사표시를 함으로서 회원가입을 신청합니다."몰"은 제1항과 같이 회원으로 가입할 것을 신청한 이용자 중 다음 각호에 해당하지 않는 한 회원으로 등록합니다. 1. 가입신청자가 이 약관 제7조제3항에 의하여 이전에 회원자격을 상실한 적이 있는 경우, 다만 제7조제3항에 의한 회원자격 상실 후 3년이 경과한 자로서 "몰"의 회원재가입 승낙을 얻은 경우에는 예외로 한다.2. 등록 내용에 허위, 기재누락, 오기가 있는 경우3. 기타 회원으로 등록하는 것이 "몰"의 기술상 현저히 지장이 있다고 판단되는 경우회원가입계약의 성립시기는 "몰"의 승낙이 회원에게 도달한 시점으로 합니다.회원은 제15조제1항에 의한 등록사항에 변경이 있는 경우, 상당한 기간이내에 몰에 대하여 회원정보수정등의 방법으로 그 변경사항을 알려야 합니다제7조(회원 탈퇴 및 자격 상실 등)회원은 "몰"에 언제든지 탈퇴를 요청할 수 있으며 "몰"은 즉시 회원탈퇴를 처리합니다.회원이 다음 각호의 사유에 해당하는 경우, "몰"은 회원자격을 제한 및 정지시킬 수 있습니다. 1. 가입 신청시에 허위 내용을 등록한 경우2. "몰"을 이용하여 구입한 재화등의 대금, 기타 "몰"이용에 관련하여 회원이 부담하는 채무를 기일에 지급하지 않는 경우3. 다른 사람의 "몰" 이용을 방해하거나 그 정보를 도용하는 등 전자상거래 질서를 위협하는 경우4. "몰"을 이용하여 법령 또는 이 약관이 금지하거나 공서양속에 반하는 행위를 하는 경우제8조(회원에 대한 통지)"몰"이 회원에 대한 통지를 하는 경우, 회원이 "몰"과 미리 약정하여 지정한 전자우편 주소로 할 수 있습니다."몰"은 불특정다수 회원에 대한 통지의 경우 1주일이상 "몰" 게시판에 게시함으로서 개별 통지에 갈음할 수 있습니다. 다만, 회원 본인의 거래와 관련하여 중대한 영향을 미치는 사항에 대하여는 개별통지를 합니다.제9조(구매신청 및 개인정보 제공 동의 등)"몰"이용자는 "몰"상에서 다음 또는 이와 유사한 방법에 의하여 구매를 신청하며, "몰"은 이용자가 구매신청을 함에 있어서 다음의 각 내용을 알기 쉽게 제공하여야 합니다. ① 재화등의 검색 및 선택② 성명, 주소, 전화번호, 전자우편주소(또는 이동전화번호) 등의 입력③ 약관내용, 청약철회권이 제한되는 서비스, 배송료ㆍ설치비 등의 비용부담과 관련한 내용에 대한 확인④ 이 약관에 동의하고 위 3호의 사항을 확인하거나 거부하는 표시(예, 마우스 클릭)⑤ 재화등의 구매신청 및 이에 관한 확인 또는 "몰"의 확인에 대한 동의⑥ 결제방법의 선택“몰”이 제3자에게 구매자 개인정보를 제공할 필요가 있는 경우 1)개인정보를 제공받는 자, 2)개인정보를 제공받는 자의 개인정보 이용목정, 3)제공하는 개인정보의 항목,4)개인정보를 제공받는 자의 개인정보 보유 및 이용기간을 구매자에게 알리고 동의를 받아야 합니다. (동의를 받은 사항이 변경되는 경우에도 같습니다.)”몰”이 제3자에게 구매 ...

# %%
a = '  !test!   '
a.strip().strip('!')
# Out:
# 'test'

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#      - -------------------------------------- 0.5/19.4 MB 11.1 MB/s eta 0:00:02
#      -- ------------------------------------- 1.1/19.4 MB 11.8 MB/s eta 0:00:02
#      --- ------------------------------------ 1.7/19.4 MB 11.8 MB/s eta 0:00:02
#      ---- ----------------------------------- 2.2/19.4 MB 11.5 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.5/19.4 MB 10.5 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.8/19.4 MB 9.3 MB/s eta 0:00:02
#      ------ --------------------------------- 3.1/19.4 MB 8.9 MB/s eta 0:00:02
#      ------ --------------------------------- 3.4/19.4 MB 8.9 MB/s eta 0:00:02
#      ------- -------------------------------- 3.7/19.4 MB 8.3 MB/s eta 0:00:02
#      -------- ------------------------------- 4.0/19.4 MB 8.1 MB/s eta 0:00:02
#      -------- ------------------------------- 4.3/19.4 MB 8.0 MB/s eta 0:00:02
#      --------- ------------------------------ 4.5/19.4 MB 7.8 MB/s eta 0:00:02
#      --------- ------------------------------ 4.8/19.4 MB 7.7 MB/s eta 0:00:02
#      ---------- ----------------------------- 5.1/19.4 MB 7.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 5.4/19.4 MB 7.5 MB/s eta 0:00:02
#      ----------- ---------------------------- 5.7/19.4 MB 7.5 MB/s eta 0:00:02
#      ------------ --------------------------- 6.0/19.4 MB 7.4 MB/s eta 0:00:02
#      ------------- -------------------------- 6.3/19.4 MB 7.3 MB/s eta 0:00:02
#      ------------- -------------------------- 6.5/19.4 MB 7.3 MB/s eta 0:00:02
#      -------------- ------------------------- 6.9/19.4 MB 7.3 MB/s eta 0:00:02
#      -------------- ------------------------- 7.2/19.4 MB 7.2 MB/s eta 0:00:02
#      --------------- ------------------------ 7.6/19.4 MB 7.2 MB/s eta 0:00:02
#      ---------------- ----------------------- 7.9/19.4 MB 7.2 MB/s eta 0:00:02
#      ---------------- ----------------------- 8.2/19.4 MB 7.2 MB/s eta 0:00:02
#      ----------------- ---------------------- 8.5/19.4 MB 7.1 MB/s eta 0:00:02
#      ------------------ --------------------- 8.8/19.4 MB 7.1 MB/s eta 0:00:02
#      ------------------ --------------------- 9.0/19.4 MB 7.0 MB/s eta 0:00:02
#      ------------------- -------------------- 9.2/19.4 MB 6.9 MB/s eta 0:00:02
#      ------------------- -------------------- 9.5/19.4 MB 6.8 MB/s eta 0:00:02
#      -------------------- ------------------- 9.8/19.4 MB 6.9 MB/s eta 0:00:02
#      -------------------- ------------------- 10.1/19.4 MB 6.9 MB/s eta 0:00:02
#      --------------------- ------------------ 10.4/19.4 MB 6.8 MB/s eta 0:00:02
#      ---------------------- ----------------- 10.7/19.4 MB 6.7 MB/s eta 0:00:02
#      ---------------------- ----------------- 11.0/19.4 MB 6.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 11.2/19.4 MB 6.5 MB/s eta 0:00:02
#      ----------------------- ---------------- 11.5/19.4 MB 6.4 MB/s eta 0:00:02
#      ------------------------ --------------- 11.8/19.4 MB 6.3 MB/s eta 0:00:02
#      ------------------------ --------------- 12.1/19.4 MB 6.2 MB/s eta 0:00:02
#      ------------------------- -------------- 12.4/19.4 MB 6.1 MB/s eta 0:00:02
#      -------------------------- ------------- 12.7/19.4 MB 6.1 MB/s eta 0:00:02
#      -------------------------- ------------- 13.0/19.4 MB 6.2 MB/s eta 0:00:02
#      --------------------------- ------------ 13.3/19.4 MB 6.2 MB/s eta 0:00:01
#      --------------------------- ------------ 13.6/19.4 MB 6.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 13.7/19.4 MB 6.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 13.8/19.4 MB 6.0 MB/s eta 0:00:01
#      ---------------------------- ----------- 14.0/19.4 MB 5.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 14.1/19.4 MB 5.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 14.3/19.4 MB 5.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 14.4/19.4 MB 5.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 14.5/19.4 MB 5.6 MB/s eta 0:00:01
#      ------------------------------ --------- 14.7/19.4 MB 5.4 MB/s eta 0:00:01
#      ------------------------------ --------- 14.8/19.4 MB 5.4 MB/s eta 0:00:01
#      ------------------------------ --------- 15.0/19.4 MB 5.3 MB/s eta 0:00:01
#      ------------------------------- -------- 15.1/19.4 MB 5.2 MB/s eta 0:00:01
#      ------------------------------- -------- 15.3/19.4 MB 5.2 MB/s eta 0:00:01
#      ------------------------------- -------- 15.3/19.4 MB 5.2 MB/s eta 0:00:01
#      ------------------------------- -------- 15.5/19.4 MB 5.0 MB/s eta 0:00:01
#      -------------------------------- ------- 15.6/19.4 MB 5.0 MB/s eta 0:00:01
#      -------------------------------- ------- 15.7/19.4 MB 4.9 MB/s eta 0:00:01
#      -------------------------------- ------- 15.8/19.4 MB 4.8 MB/s eta 0:00:01
#      -------------------------------- ------- 16.0/19.4 MB 4.8 MB/s eta 0:00:01
#      --------------------------------- ------ 16.1/19.4 MB 4.7 MB/s eta 0:00:01
#      --------------------------------- ------ 16.2/19.4 MB 4.6 MB/s eta 0:00:01
#      --------------------------------- ------ 16.4/19.4 MB 4.6 MB/s eta 0:00:01
#      --------------------------------- ------ 16.5/19.4 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 16.6/19.4 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 16.8/19.4 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 17.0/19.4 MB 4.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 17.2/19.4 MB 4.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 17.4/19.4 MB 4.3 MB/s eta 0:00:01
#      ------------------------------------ --- 17.5/19.4 MB 4.3 MB/s eta 0:00:01
#      ------------------------------------ --- 17.7/19.4 MB 4.3 MB/s eta 0:00:01
#      ------------------------------------ --- 17.8/19.4 MB 4.2 MB/s eta 0:00:01
#      ------------------------------------ --- 18.0/19.4 MB 4.2 MB/s eta 0:00:01
#      ------------------------------------- -- 18.1/19.4 MB 4.1 MB/s eta 0:00:01
#      ------------------------------------- -- 18.2/19.4 MB 4.1 MB/s eta 0:00:01
#      ------------------------------------- -- 18.4/19.4 MB 4.1 MB/s eta 0:00:01
#      -------------------------------------- - 18.6/19.4 MB 4.0 MB/s eta 0:00:01
#      -------------------------------------- - 18.7/19.4 MB 4.0 MB/s eta 0:00:01
#      -------------------------------------- - 18.9/19.4 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  19.1/19.4 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  19.2/19.4 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  19.4/19.4 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  19.4/19.4 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------- 19.4/19.4 MB 3.8 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.4.1-cp310-cp310-win_amd64.whl (345 kB)
#      ---------------------------------------- 0.0/345.1 kB ? eta -:--:--
#      -------- ------------------------------ 71.7/345.1 kB 2.0 MB/s eta 0:00:01
#      ------------------------ ------------- 225.3/345.1 kB 2.8 MB/s eta 0:00:01
#      -------------------------------------- 345.1/345.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from konlpy) (4.9.3)
# Requirement already satisfied: numpy>=1.6 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from konlpy) (1.25.1)
# Requirement already satisfied: packaging in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0

# %%
# 라이브러리 로드
from konlpy.tag import Okt
from konlpy.tag import Kkma

# %%
# Okt() class 생성
okt = Okt()

# %%
nouns = okt.nouns(privacy_data)

# %%
kkma = Kkma()

# %%
kkma.nouns(privacy_data)
# Out:
# ['저',
#  '1',
#  '1조',
#  '조',
#  '목적',
#  '이',
#  '약관',
#  '씨',
#  '씨앤피물류',
#  '앤',
#  '피',
#  '물류',
#  '회사',
#  '전자',
#  '전자거래',
#  '거래',
#  '사업자',
#  '운영',
#  '사이버',
#  '몰',
#  '이하',
#  '제공',
#  '인터넷',
#  '관련',
#  '서비스',
#  '라',
#  '이용',
#  '사이버몰',
#  '이용자',
#  '권리',
#  '권리ㆍ의무',
#  'ㆍ',
#  '의무',
#  '책임',
#  '책임사항',
#  '사항',
#  '규정',
#  '통신',
#  '통신등',
#  '등',
#  '성질',
#  '한',
#  '준용',
#  '2',
#  '2조',
#  '정의',
#  '재화',
#  '용역',
#  '컴퓨터',
#  '컴퓨터등',
#  '정보',
#  '정보통신설비',
#  '설비',
#  '수',
#  '설정',
#  '가상',
#  '영업장',
#  '의미',
#  '접속',
#  '회원',
#  '비',
#  '비회원',
#  '함',
#  '개인',
#  '개인정보',
#  '회원등록',
#  '등록',
#  '자로',
#  '계속적',
#  '자',
#  '가입',
#  '3',
#  '3조',
#  '약관등',
#  '명시',
#  '설명',
#  '개정',
#  '은',
#  '내용',
#  '상호',
#  '대표자',
#  '성명',
#  '영',
#  '영업소',
#  '업소',
#  '소재지',
#  '주소',
#  '소비자',
#  '불만',
#  '처리',
#  '곳',
#  '포함',
#  '전화번호',
#  '전화번호ㆍ모사전송',
#  '모사',
#  '전송',
#  '번호',
#  '번호ㆍ전자우편',
#  '우편',
#  '사업자등록번호',
#  '통신판매업신고번호',
#  '판매업',
#  '신고',
#  '개인정보관리책임자',
#  '관리',
#  '책임자',
#  '의',
#  '초기',
#  '초기서비스화면',
#  '화면',
#  '전면',
#  '게시',
#  '연결',
#  '연결화면',
#  '동의',
#  '중',
#  '청약',
#  '청약철회ㆍ배송',
#  '철회',
#  '배송',
#  '책임ㆍ환불조건',
#  '환불',
#  '조건',
#  '중요',
#  '이해',
#  '별도',
#  '팝업',
#  '팝업화면',
#  '확인',
#  '전자상거래등',
#  '상거래',
#  '소비자보호',
#  '보호',
#  '법률',
#  '규제',
#  '전자문서',
#  '문서',
#  '전자거래기본법',
#  '기본법',
#  '전자금융거래법',
#  '금융',
#  '거래법',
#  '명법',
#  '정보통신망',
#  '통신망',
#  '이용촉진',
#  '촉진',
#  '정보보호',
#  '방문',
#  '방문판매',
#  '판매',
#  '소비자보호법',
#  '보호법',
#  '관련법',
#  '법',
#  '위배',
#  '범위',
#  '경우',
#  '적용',
#  '적용일자',
#  '일자',
#  '개정사유',
#  '사유',
#  '현행',
#  '현행약관',
#  '초기화면',
#  '7',
#  '7일이전',
#  '일',
#  '이전',
#  '전일',
#  '공지',
#  '불리',
#  '약관내용',
#  '변경',
#  '최소한',
#  '30',
#  '30일',
#  '이상',
#  '사전',
#  '유예',
#  '유예기간',
#  '기간',
#  '이',
#  '개정전',
#  '전',
#  '개정후',
#  '후',
#  '비교',
#  '표시',
#  '개정약관',
#  '이후',
#  '체결',
#  '계약',
#  '약관조항',
#  '조항',
#  '뜻',
#  '3항',
#  '항',
#  '공지기간내',
#  '내',
#  '송신',
#  '해석',
#  '공정',
#  '공정거래위원회',
#  '위원회',
#  '전자상거래',
#  '소비자보호지침',
#  '지침',
#  '관계',
#  '관계법령',
#  '법령',
#  '상',
#  '상관례',
#  '관례',
#  '4',
#  '4조',
#  '다음',
#  '업무',
#  '수행',
#  '구매',
#  '구매계약',
#  '기타',
#  '품질',
#  '기술적',
#  '사양',
#  '제공일자',
#  '현재',
#  '즉시',
#  '통지',
#  '가능',
#  '전항',
#  '입',
#  '손해',
#  '배상',
#  '고의',
#  '과실',
#  '입증',
#  '5',
#  '5조',
#  '중단',
#  '본',
#  '상품',
#  '변심',
#  '반품',
#  '반송',
#  '반송비',
#  '고객',
#  '부담',
#  '초기배송료',
#  '배',
#  '송료',
#  '왕복',
#  '왕복배송',
#  '해당',
#  '금액',
#  '보수',
#  '보수점검ㆍ교체',
#  '점검',
#  '교체',
#  '고장',
#  '두절',
#  '발생',
#  '일시적',
#  '제',
#  '제1항',
#  '공이',
#  '3자',
#  '자',
#  '단',
#  '사업',
#  '사업종목',
#  '종목',
#  '전환',
#  '포기',
#  '업체',
#  '업체간의',
#  '간의',
#  '통합',
#  '이유',
#  '제8조',
#  '8',
#  '조',
#  '방법',
#  '당초',
#  '제시',
#  '보상',
#  '보상기준',
#  '기준',
#  '고지',
#  '통용',
#  '통화',
#  '통화가치',
#  '가치',
#  '상응',
#  '현물',
#  '현금',
#  '지급',
#  '6',
#  '6조',
#  '회원가입',
#  '정한',
#  '양식',
#  '회원정보',
#  '기입',
#  '의사',
#  '의사표시',
#  '신청',
#  '각호',
#  '가입신청자',
#  '신청자',
#  '제7조제',
#  '회원자격',
#  '자격',
#  '상실',
#  '7조제3',
#  '3년',
#  '년',
#  '경과',
#  '승낙',
#  '예외',
#  '허위',
#  '기재',
#  '기재누락',
#  '누락',
#  '오기',
#  '기술상',
#  '지장',
#  '판단',
#  '회원가입계약',
#  '성립',
#  '성립시기',
#  '시기',
#  '도달',
#  '시점',
#  '15',
#  '15조제1',
#  '등록사항',
#  '상당',
#  '기간이내',
#  '이내',
#  '회원정보수정등',
#  '수정',
#  '변경사항',
#  '7조',
#  '탈퇴',
#  '언제',
#  '요청',
#  '회원탈퇴',
#  '제한',
#  '정지',
#  '신청시',
#  '시',
#  '을',
#  '구입',
#  '재화등',
#  '대금',
#  '채',
#  '기일',
#  '사람',
#  '방해',
#  '도용',
#  '질서',
#  '위협',
#  '금지',
#  '공서',
#  '공서양속',
#  '양속',
#  '행위',
#  '과',
#  '약정',
#  '지정',
#  '전자우편',
#  '불특정',
#  '불특정다수',
#  '다수',
#  '1주일이상',
#  '주일',
#  '게시판',
#  '개별',
#  '갈음',
#  '본인',
#  '중대',
#  '영향',
#  '개별통지',
#  '9',
#  '9조',
#  '구매신청',
#  '이',
#  '유사',
#  '검색',
#  '선택',
#  '전자우편주소',
#  '이동',
#  '이동전화번호',
#  '전화',
#  '입력',
#  '청약철회',
#  '배송료ㆍ설치',
#  '설치',
#  '비용',
#  '비용부담',
#  '위',
#  '3호',
#  '호',
#  '거부',
#  '예',
#  '마우스',
#  '클릭',
#  '관',
#  '결제',
#  '결제방법',
#  '제3자',
#  '구매자',
#  '필요',
#  '자',
#  '자의',
#  '이용목정',
#  '목정',
#  '항목',
#  '보유',
#  '이용기간',
#  '취급',
#  '위탁',
#  '취급위탁',
#  '계약이행',
#  '이행',
#  '편의',
#  '편의증진',
#  '증진',
#  '취급방침',
#  '방침',
#  '고지절차',
#  '절차',
#  '10',
#  '10조',
#  '제9조',
#  '성년자',
#  '법정',
#  '대리인',
#  '취소',
#  '애',
#  '애용을',
#  '용을',
#  '신',
#  '청',
#  '담배',
#  '주류',
#  '청소년',
#  '청소년보호법',
#  '12',
#  '12조제1',
#  '수신',
#  '통지형태',
#  '형태',
#  '판매가능',
#  '여부',
#  '정정',
#  '11',
#  '11조',
#  '지급방법',
#  '대금지급방법',
#  '방법중',
#  '가용',
#  '명목',
#  '수수료',
#  '추가',
#  '징수',
#  '폰',
#  '폰뱅킹',
#  '뱅킹',
#  '인터넷뱅킹',
#  '메일',
#  '각종',
#  '계좌',
#  '계좌이체',
#  '이체',
#  '선불',
#  '선불카드',
#  '카드',
#  '직불',
#  '직불카드',
#  '신용',
#  '신용카드',
#  '온라인',
#  '통장',
#  '통장입금',
#  '입금',
#  '전자화폐',
#  '화폐',
#  '수령',
#  '수령시',
#  '대금지급',
#  '마일리지',
#  '포인트',
#  '맺었거',
#  '인정',
#  '상품권',
#  '12조',
#  '수신확인통지ㆍ',
#  '수신확인통지',
#  '불일치',
#  '불일치등',
#  '배송전',
#  '지체',
#  '지불',
#  '15조의',
#  '조의',
#  '13',
#  '13조',
#  '공급',
#  '공급시기',
#  '날',
#  '7일',
#  '주문',
#  '주문제작',
#  '제작',
#  '포장',
#  '조치',
#  '전부',
#  '일부',
#  '3영업일',
#  '영업',
#  '이때',
#  '진행',
#  '배송수단',
#  '수단',
#  '배송비용',
#  '부담자',
#  '배송기간',
#  '만약',
#  '초과',
#  '그',
#  '고의ㆍ과실',
#  '14',
#  '14조',
#  '환급',
#  '품절',
#  '인도',
#  '때',
#  '영업일',
#  '일',
#  '3일',
#  '15조',
#  '2항',
#  '서면',
#  '시작',
#  '동',
#  '호의',
#  '교환',
#  '멸실',
#  '훼손',
#  '사용',
#  '소비',
#  '감소',
#  '시간',
#  '재판매',
#  '곤란',
#  '정도',
#  '단순',
#  '제품',
#  '제품구매',
#  '사전확인',
#  '동의서',
#  '원칙',
#  '제2항',
#  '2호',
#  '4호',
#  '사실',
#  '명기',
#  '사용상품',
#  '1항',
#  '표시ㆍ광고',
#  '광고',
#  '계약내용',
#  '당해',
#  '3일이내',
#  '16',
#  '16조',
#  '효과',
#  '이용자로',
#  '반환',
#  '지연',
#  '지연기간',
#  '시행령',
#  '21',
#  '21조2',
#  '조',
#  '자연',
#  '자율',
#  '산정',
#  '지연이자',
#  '이자',
#  '결제수단',
#  '청구',
#  '청약철회등',
#  '위약금',
#  '손해배상',
#  '배송비',
#  '청약철회시',
#  '누',
#  '지',
#  '17',
#  '17조',
#  '개인정보보호',
#  '정보수집',
#  '수집',
#  '필수',
#  '필수사항',
#  '외',
#  '선택사항',
#  '희망',
#  '비밀',
#  '비밀번호',
#  '개',
#  '개인식',
#  '인식',
#  '회원가입시',
#  '입시',
#  '구매계약이행',
#  '본인확인',
#  '특정',
#  '목적외의',
#  '외의',
#  '새',
#  '이용목적',
#  '제공단계',
#  '단계',
#  '배송업무상',
#  '배송업체',
#  '통계',
#  '통계작성',
#  '작성',
#  '학술',
#  '학술연구',
#  '연구',
#  '시장',
#  '시장조사',
#  '조사',
#  '식별',
#  '대금정산',
#  '정산',
#  '도용방지',
#  '방지',
#  '개인정보관리',
#  '신원',
#  '소속',
#  '연락처',
#  '수집목적',
#  '정보제공',
#  '관련사항',
#  '제공목적',
#  '이용촉진등',
#  '제22조제',
#  '22',
#  '자신',
#  '열람',
#  '오류',
#  '오류정정',
#  '요구',
#  '은행',
#  '은행계좌',
#  '분실',
#  '도난',
#  '유',
#  '변조',
#  '그로',
#  '달성',
#  '파기',
#  '란',
#  '동의거절',
#  '거절',
#  '구체적',
#  '필수수집항목',
#  '18',
#  '18조',
#  '바',
#  '지속적',
#  '안정적',
#  '재화ㆍ용역',
#  '최선',
#  '안전',
#  '신용정보',
#  '보안',
#  '시스템',
#  '소정',
#  '부당',
#  '표시ㆍ광고행위',
#  '영리',
#  '영리목적',
#  '발송',
#  '19',
#  '19조',
#  '제외',
#  '관리책임',
#  '있음',
#  '인지',
#  '통보',
#  '안내',
#  '20',
#  '20조',
#  '변',
#  '변경시',
#  '경시',
#  '타인',
#  '정',
#  '이외',
#  '프로그램',
#  '저작권',
#  '지적',
#  '지적재산권',
#  '재산권',
#  '침해',
#  '명예',
#  '손상',
#  '외설',
#  '폭력적',
#  '메시지',
#  '화상',
#  '음성',
#  '공공',
#  '선량',
#  '풍속',
#  '공개',
#  '제21조',
#  '연',
#  '결',
#  '피연결',
#  '상위',
#  '하위',
#  '하이퍼',
#  '하이퍼링크',
#  '링크',
#  '대상',
#  '문자',
#  '그림',
#  '동화상',
#  '방식',
#  '웹',
#  '사이트',
#  '후자',
#  '웹사이트',
#  '독자적',
#  '보증',
#  '시점의',
#  '22조',
#  '귀속',
#  '이용제한',
#  '저작물',
#  '복제',
#  '출판',
#  '배포',
#  '방송',
#  '23',
#  '23조',
#  '분쟁',
#  '분쟁해결',
#  '해결',
#  '제기',
#  '의견',
#  '반영',
#  '피해',
#  '보상처리',
#  '피해보상처리기구',
#  '기구',
#  '설치ㆍ운영',
#  '제출',
#  '불만사항',
#  '우선적',
#  '신속',
#  '처리일정',
#  '일정',
#  '이용자간',
#  '간',
#  '피해구제신청',
#  '구제',
#  '시ㆍ도지사',
#  '의뢰',
#  '분쟁조정기관',
#  '조정',
#  '기관',
#  '24',
#  '24조',
#  '재판권',
#  '준거법',
#  '소송',
#  '제소',
#  '당시',
#  '거소',
#  '관할',
#  '지방',
#  '지방법원',
#  '법원',
#  '전속',
#  '전속관할',
#  '분명',
#  '외국',
#  '거주자',
#  '민사',
#  '민사소송법',
#  '소송법',
#  '상의',
#  '관할법원',
#  '한국',
#  '한국법']

# %%
# 리스트에서 글자수가 1인 데이터를 제거
words = []

for i in nouns:
    # 단어의 길이가 1보다 큰 경우
    if len(i) > 1:
        # words 리스트에 i를 추가
        words.append(i)

words
# Out:
# ['목적',
#  '약관',
#  '씨앤피',
#  '물류',
#  '회사',
#  '전자거래',
#  '사업자',
#  '운영',
#  '씨앤피',
#  '물류',
#  '사이버',
#  '이하',
#  '제공',
#  '인터넷',
#  '관련',
#  '서비스',
#  '이하',
#  '서비스',
#  '이용',
#  '사이버',
#  '이용자',
#  '권리',
#  '의무',
#  '책임',
#  '사항',
#  '규정',
#  '목적',
#  '통신',
#  '이용',
#  '전자거래',
#  '대해',
#  '서도',
#  '성질',
#  '약관',
#  '준용',
#  '정의',
#  '이란',
#  '씨앤피',
#  '물류',
#  '회사',
#  '재화',
#  '용역',
#  '이용자',
#  '제공',
#  '컴퓨터',
#  '정보통',
#  '설비',
#  '이용',
#  '재화',
#  '용역',
#  '거래',
#  '설정',
#  '가상',
#  '영업',
#  '사이버',
#  '운영',
#  '사업자',
#  '의미',
#  '사용',
#  '이용자',
#  '접속',
#  '약관',
#  '제공',
#  '서비스',
#  '회원',
#  '비회',
#  '회원',
#  '개인정보',
#  '제공',
#  '회원',
#  '등록',
#  '자로',
#  '계속',
#  '제공',
#  '서비스',
#  '이용',
#  '비회',
#  '회원',
#  '가입',
#  '제공',
#  '서비스',
#  '이용',
#  '관등',
#  '명시',
#  '설명',
#  '개정',
#  '약관',
#  '내용',
#  '상호',
#  '대표자',
#  '성명',
#  '영업소',
#  '소재지',
#  '주소',
#  '소비자',
#  '불만',
#  '처리',
#  '주소',
#  '포함',
#  '전화번호',
#  '전송',
#  '번호',
#  '전자우편',
#  '주소',
#  '사업자',
#  '등록',
#  '번호',
#  '통신',
#  '판매업',
#  '신고',
#  '번호',
#  '개인정보',
#  '관리',
#  '책임',
#  '자등',
#  '이용자',
#  '초기',
#  '서비스',
#  '화면',
#  '전면',
#  '게시',
#  '다만',
#  '약관',
#  '내용',
#  '이용자',
#  '연결',
#  '화면',
#  '이용자',
#  '약관',
#  '동의',
#  '앞서',
#  '약관',
#  '내용',
#  '청약',
#  '철회',
#  '배송',
#  '책임',
#  '환불',
#  '조건',
#  '내용',
#  '이용자',
#  '이해',
#  '별도',
#  '연결',
#  '화면',
#  '팝업',
#  '화면',
#  '제공',
#  '이용자',
#  '확인',
#  '전자상거래',
#  '소비자보호',
#  '법률',
#  '약관',
#  '규제',
#  '법률',
#  '전자문서',
#  '전자거래',
#  '기본',
#  '전자',
#  '금융',
#  '거래',
#  '전자서명',
#  '정보통신망',
#  '이용',
#  '촉진',
#  '정보보호',
#  '법률',
#  '방문',
#  '판매',
#  '법률',
#  '소비자보호법',
#  '관련',
#  '배하',
#  '범위',
#  '약관',
#  '개정',
#  '약관',
#  '개정',
#  '경우',
#  '적용',
#  '일자',
#  '개정',
#  '사유',
#  '명시',
#  '현행',
#  '약관',
#  '초기',
#  '화면',
#  '적용',
#  '일자',
#  '적용',
#  '일자',
#  '전일',
#  '공지',
#  '다만',
#  '이용자',
#  '약관',
#  '내용',
#  '변경',
#  '경우',
#  '최소한',
#  '이상',
#  '사전',
#  '유예',
#  '기간',
#  '공지',
#  '경우',
#  '정전',
#  '내용',
#  '개정',
#  '내용',
#  '비교',
#  '이용자',
#  '표시',
#  '약관',
#  '개정',
#  '경우',
#  '개정',
#  '약관',
#  '적용',
#  '일자',
#  '이후',
#  '체결',
#  '계약',
#  '적용',
#  '이전',
#  '체결',
#  '계약',
#  '대해',
#  '개정',
#  '전의',
#  '약관',
#  '조항',
#  '그대로',
#  '적용',
#  '다만',
#  '계약',
#  '체결',
#  '이용자',
#  '개정',
#  '약관',
#  '조항',
#  '적용',
#  '개정',
#  '약관',
#  '기간',
#  '송신',
#  '동의',
#  '경우',
#  '개정',
#  '약관',
#  '조항',
#  '적용',
#  '약관',
#  '사항',
#  '약관',
#  '해석',
#  '전자상거래',
#  '소비자보호',
#  '법률',
#  '약관',
#  '규제',
#  '법률',
#  '정거',
#  '위원회',
#  '전자상거래',
#  '소비자보호',
#  '지침',
#  '관계',
#  '법령',
#  '관례',
#  '서비스',
#  '제공',
#  '변경',
#  '다음',
#  '업무',
#  '수행',
#  '재화',
#  '용역',
#  '대한',
#  '정보',
#  '제공',
#  '계약',
#  '체결',
#  '계약',
#  '체결',
#  '재화',
#  '용역',
#  '배송',
#  '기타',
#  '업무',
#  '재화',
#  '용역',
#  '품질',
#  '기술',
#  '사양',
#  '변경',
#  '경우',
#  '장차',
#  '체결',
#  '계약',
#  '제공',
#  '재화',
#  '용역',
#  '내용',
#  '변경',
#  '경우',
#  '변경',
#  '재화',
#  '용역',
#  '내용',
#  '일자',
#  '명시',
#  '현재',
#  '재화',
#  '용역',
#  '내용',
#  '게시',
#  '즉시',
#  '공지',
#  '제공',
#  '이용자',
#  '계약',
#  '체결',
#  '서비스',
#  '내용',
#  '재화',
#  '품질',
#  '기술',
#  '사양',
#  '변경',
#  '사유',
#  '변경',
#  '경우',
#  '사유',
#  '이용자',
#  '통지',
#  '주소',
#  '즉시',
#  '통지',
#  '항의',
#  '경우',
#  '이로',
#  '이용자',
#  '손해',
#  '배상',
#  '다만',
#  '고의',
#  '과실',
#  '입증',
#  '경우',
#  '서비스',
#  '중단',
#  '상품',
#  '변심',
#  '반품',
#  '경우',
#  '반송',
#  '고객',
#  '부담',
#  '초기',
#  '송료',
#  '포함',
#  '왕복',
#  '송료',
#  '해당',
#  '금액',
#  '고객',
#  '부담',
#  '컴퓨터',
#  '정보통',
#  '설비',
#  '보수',
#  '점검',
#  '교체',
#  '고장',
#  '통신',
#  '두절',
#  '사유',
#  '발생',
#  '경우',
#  '서비스',
#  '제공',
#  '일시',
#  '중단',
#  '항의',
#  '사유',
#  '서비스',
#  '제공',
#  '일시',
#  '중단',
#  '이용자',
#  '자가',
#  '손해',
#  '대하',
#  '배상',
#  '고의',
#  '과실',
#  '입증',
#  '경우',
#  '사업',
#  '종목',
#  '전환',
#  '사업',
#  '포기',
#  '업체',
#  '통합',
#  '이유',
#  '서비스',
#  '제공',
#  '경우',
#  '방법',
#  '이용자',
#  '통지',
#  '당초',
#  '제시',
#  '조건',
#  '소비자',
#  '보상',
#  '다만',
#  '보상',
#  '기준',
#  '고지',
#  '경우',
#  '통용',
#  '통화',
#  '가치',
#  '상응',
#  '현물',
#  '현금',
#  '이용자',
#  '지급',
#  '회원',
#  '가입',
#  '이용자',
#  '가입',
#  '양식',
#  '회원정보',
#  '기입',
#  '약관',
#  '동의',
#  '의사표시',
#  '회원',
#  '가입',
#  '신청',
#  '회원',
#  '가입',
#  '신청',
#  '이용자',
#  '다음',
#  '해당',
#  '회원',
#  '등록',
#  '가입',
#  '신청',
#  '약관',
#  '이전',
#  '회원',
#  '자격',
#  '경우',
#  '다만',
#  '회원',
#  '자격',
#  '상실',
#  '경과',
#  '자로',
#  '회원',
#  '가입',
#  '승낙',
#  '경우',
#  '예외',
#  '등록',
#  '내용',
#  '허위',
#  '기재',
#  '누락',
#  '오기',
#  '경우',
#  '기타',
#  '회원',
#  '등록',
#  '기술',
#  '현저',
#  '지장',
#  '판단',
#  '경우',
#  '회원',
#  '가입',
#  '계약',
#  '성립',
#  '시기',
#  '승낙',
#  '회원',
#  '도달',
#  '시점',
#  '회원',
#  '등록',
#  '사항',
#  '변경',
#  '경우',
#  '기간',
#  '이내',
#  '대하',
#  '회원정보',
#  '수정',
#  '방법',
#  '변경',
#  '사항',
#  '회원',
#  '탈퇴',
#  '자격',
#  '상실',
#  '회원',
#  '언제',
#  '탈퇴',
#  '요청',
#  '즉시',
#  '회원',
#  '탈퇴',
#  '처리',
#  '회원',
#  '다음',
#  '호의',
#  '사유',
#  '해당',
#  '경우',
#  '회원',
#  '자격',
#  '제한',
#  '정지',
#  '가입',
#  '신청',
#  '허위',
#  '내용',
#  '등록',
#  '경우',
#  '이용',
#  '구입',
#  '재화',
#  '대금',
#  '기타',
#  '이용',
#  '관련',
#  '회원',
#  '부담',
#  '채무',
#  '기일',
#  '지급',
#  '경우',
#  '다른',
#  '사람',
#  '이용',
#  '정보',
#  '도용',
#  '전자상거래',
#  '질서',
#  '위협',
#  '경우',
#  '이용',
#  '법령',
#  '약관',
#  '금지',
#  '거나',
#  '양속',
#  '행위',
#  '경우',
#  '회원',
#  '대한',
#  '통지',
#  '회원',
#  '대한',
#  '통지',
#  '경우',
#  '회원',
#  '미리',
#  '약정',
#  '지정',
#  '전자우편',
#  '주소',
#  '특정',
#  '다수',
#  '회원',
#  '대한',
#  '통지',
#  '경우',
#  '주일',
#  '이상',
#  '게시판',
#  '게시',
#  '개별',
#  '통지',
#  '다만',
#  '회원',
#  '본인',
#  '거래',
#  '관련',
#  '영향',
#  '사항',
#  '대하',
#  '개별',
#  '통지',
#  '구매',
#  '신청',
#  '개인정보',
#  '제공',
#  '동의',
#  '이용자',
#  '다음',
#  '방법',
#  '구매',
#  '신청',
#  '이용자',
#  '신청',
#  '다음',
#  '내용',
#  '제공',
#  '재화',
#  '검색',
#  '선택',
#  '성명',
#  '주소',
#  '전화번호',
#  '전자우편',
#  '주소',
#  '이동전화',
#  '번호',
#  '입력',
#  '약관',
#  '내용',
#  '청약',
#  '철회',
#  '제한',
#  '서비스',
#  '송료',
#  '설치',
#  '비용',
#  '부담',
#  '관련',
#  '내용',
#  '대한',
#  '확인',
#  '약관',
#  '동의',
#  '호의',
#  '사항',
#  '확인',
#  '거나',
#  '거부',
#  '표시',
#  '마우스',
#  '클릭',
#  '재화',
#  '구매',
#  '신청',
#  '확인',
#  '확인',
#  '대한',
#  '동의',
#  '결제',
#  '방법',
#  '선택',
#  '구매',
#  '개인정보',
#  '제공',
#  '필요',
#  '경우',
#  '개인정보',
#  '제공',
#  '개인정보',
#  '제공',
#  '자의',
#  '개인정보',
#  '이용',
#  '목정',
#  '제공',
#  '개인정보',
#  '항목',
#  '개인정보',
#  '제공',
#  '자의',
#  '개인정보',
#  '보유',
#  '이용기',
#  '구매',
#  '알리',
#  '동의',
#  '동의',
#  '사항',
#  '변경',
#  '경우',
#  '구매',
#  '자의',
#  '개인정보',
#  '취급',
#  '업무',
#  '위탁',
#  '경우',
#  '개인정보',
#  '취급',
#  '위탁',
#  '개인정보',
#  '취급',
#  '위탁',
#  '업무',
#  '내용',
#  '구매',
#  '알리',
#  '동의',
#  '동의',
#  '사항',
#  '변경',
#  '경우',
#  '다만',
#  '서비스',
#  '제공',
#  '계약',
#  '이행',
#  '위해',
#  '구매',
#  '자의',
#  '편의',
#  '증진',
#  '관련',
#  '경우',
#  '정보통신망',
#  '이용',
#  '촉진',
#  '정보보호',
#  '법률',
#  '방법',
#  '개인정보',
#  '취급',
#  '방침',
#  '통해',
#  '알림',
#  '고지',
#  '절차',
#  '동의',
#  '절차',
#  '거치',
#  '계약',
#  '성립',
#  '신청',
#  '대하',
#  '다음',
#  '해당',
#  '승낙',
#  '다만',
#  '미성년',
#  '계약',
#  '체결',
#  '경우',
#  '법정',
#  '대리인',
#  '동의',
#  '얻지',
#  '미성년',
#  '본인',
#  '법정',
#  '대리인',
#  '계약',
#  '취소',
#  '애용',
#  '고지',
#  '신청',
#  '내용',
#  '허위',
#  '기재',
#  '누락',
#  '오기',
#  '경우',
#  '미성년',
#  '담배',
#  '주류',
#  '청소년',
#  '보호',
#  '금지',
#  '재화',
#  '용역',
#  '구매',
#  '경우',
#  '기타',
#  '신청',
#  '승낙',
#  '기술',
#  '현저',
#  '지장',
#  '판단',
#  '경우',
#  '승낙',
#  '항의',
#  '확인',
#  '통지',
#  '형태',
#  '이용자',
#  '도달',
#  '시점',
#  '계약',
#  '성립',
#  '승낙',
#  '의사표시',
#  '이용자',
#  '구매',
#  '신청',
#  '대한',
#  '확인',
#  '판매',
#  '가능',
#  '여부',
#  '신청',
#  '정정',
#  '취소',
#  '정보',
#  '포함',
#  '지급',
#  '방법',
#  '구매',
#  '재화',
#  '용역',
#  '대한',
#  '금지',
#  '방법',
#  '다음',
#  '호의',
#  '방법',
#  '가용',
#  '방법',
#  '이용자',
#  '지급',
#  '방법',
#  '대하',
#  '재화',
#  '대금',
#  '명목',
#  '수수료',
#  '추가',
#  '징수',
#  '뱅킹',
#  '인터넷',
#  '뱅킹',
#  '메일',
#  '뱅킹',
#  '각종',
#  '계좌',
#  '이체',
#  '선불카드',
#  '직불카드',
#  '신용카드',
#  '각종',
#  '카드',
#  '결제',
#  '온라인',
#  '통장',
#  '입금',
#  '전자화폐',
#  '결제',
#  '수령',
#  '대금',
#  '지급',
#  '마일리지',
#  '지급',
#  '포인트',
#  '결제',
#  '계약',
#  '인정',
#  '상품권',
#  '결제',
#  '기타',
#  '전자',
#  '지급',
#  '방법',
#  '대금',
#  '지급',
#  '확인',
#  '통지',
#  '구매',
#  '신청',
#  '변경',
#  '취소',
#  '이용자',
#  '신청',
#  '경우',
#  '이용자',
#  '확인',
#  '통지',
#  '확인',
#  '통지',
#  '이용자',
#  '의사표시',
#  '일치',
#  '경우',
#  '확인',
#  '통지',
#  '즉시',
#  '구매',
#  '신청',
#  '변경',
#  '취소',
#  '요청',
#  '송전',
#  '이용자',
#  '요청',
#  '경우',
#  '지체',
#  '요청',
#  '처리',
#  '다만',
#  '대금',
#  '지불',
#  '경우',
#  '청약',
#  '철회',
#  '규정',
#  '재화',
#  '공급',
#  '이용자',
#  '재화',
#  '공급',
#  '시기',
#  '별도',
#  '공지',
#  '이상',
#  '이용자',
#  '청약',
#  '이내',
#  '재화',
#  '배송',
#  '주문',
#  '제작',
#  '포장',
#  '기타',
#  '조치',
#  '취합니',
#  '다만',
#  '재화',
#  '대금',
#  '전부',
#  '일부',
#  '경우',
#  '대금',
#  '전부',
#  '일부',
#  '영업일',
#  '이내',
#  '조치',
#  '취합니',
#  '이용자',
#  '재화',
#  '공급',
#  '절차',
#  '진행',
#  '사항',
#  '확인',
#  '조치',
#  '이용자',
#  '구매',
#  '재화',
#  '대해',
#  '배송',
#  '수단',
#  '수단',
#  '배송',
#  '비용',
#  '부담',
#  '수단',
#  '배송',
#  '기간',
#  '명시',
#  '만약',
#  '약정',
#  '배송',
#  '기간',
#  '초과',
#  '경우',
#  '그로',
#  '이용자',
#  '손해',
#  '배상',
#  '다만',
#  '고의',
#  '과실',
#  '입증',
#  '경우',
#  '환급',
#  '이용자',
#  '구매',
#  '신청',
#  '재화',
#  '품절',
#  '사유',
#  '인도',
#  '제공',
#  '지체',
#  '사유',
#  '이용자',
#  '통지',
#  '사전',
#  '재화',
#  '대금',
#  ...]

# %%
# def change(x):
#     if len(x) > 1:
#        return x
# list(
#     map(
#         change,
#         nouns
#     )
# )
# Out:
# [None,
#  '목적',
#  None,
#  '약관',
#  None,
#  '씨앤피',
#  '물류',
#  '회사',
#  '전자거래',
#  '사업자',
#  '운영',
#  None,
#  '씨앤피',
#  '물류',
#  '사이버',
#  '이하',
#  '제공',
#  '인터넷',
#  '관련',
#  '서비스',
#  '이하',
#  '서비스',
#  None,
#  '이용',
#  None,
#  '사이버',
#  '이용자',
#  '권리',
#  '의무',
#  None,
#  '책임',
#  '사항',
#  '규정',
#  None,
#  '목적',
#  '통신',
#  None,
#  '이용',
#  '전자거래',
#  '대해',
#  '서도',
#  None,
#  '성질',
#  None,
#  '약관',
#  '준용',
#  None,
#  '정의',
#  '이란',
#  None,
#  '씨앤피',
#  '물류',
#  '회사',
#  '재화',
#  '용역',
#  '이용자',
#  '제공',
#  None,
#  '컴퓨터',
#  None,
#  '정보통',
#  '설비',
#  '이용',
#  '재화',
#  '용역',
#  '거래',
#  '설정',
#  '가상',
#  '영업',
#  None,
#  '사이버',
#  '운영',
#  '사업자',
#  '의미',
#  None,
#  '사용',
#  '이용자',
#  None,
#  '접속',
#  None,
#  '약관',
#  None,
#  '제공',
#  '서비스',
#  '회원',
#  None,
#  '비회',
#  None,
#  '회원',
#  None,
#  '개인정보',
#  '제공',
#  '회원',
#  '등록',
#  '자로',
#  '계속',
#  None,
#  '제공',
#  '서비스',
#  '이용',
#  None,
#  None,
#  '비회',
#  None,
#  '회원',
#  '가입',
#  None,
#  '제공',
#  '서비스',
#  '이용',
#  None,
#  None,
#  '관등',
#  '명시',
#  '설명',
#  None,
#  '개정',
#  None,
#  None,
#  '약관',
#  '내용',
#  '상호',
#  None,
#  '대표자',
#  '성명',
#  '영업소',
#  '소재지',
#  '주소',
#  '소비자',
#  '불만',
#  '처리',
#  None,
#  None,
#  '주소',
#  '포함',
#  '전화번호',
#  '전송',
#  '번호',
#  '전자우편',
#  '주소',
#  '사업자',
#  '등록',
#  '번호',
#  '통신',
#  '판매업',
#  '신고',
#  '번호',
#  '개인정보',
#  '관리',
#  '책임',
#  '자등',
#  '이용자',
#  None,
#  None,
#  None,
#  '초기',
#  '서비스',
#  '화면',
#  '전면',
#  '게시',
#  '다만',
#  '약관',
#  '내용',
#  '이용자',
#  '연결',
#  '화면',
#  None,
#  None,
#  None,
#  None,
#  None,
#  '이용자',
#  '약관',
#  '동의',
#  '앞서',
#  '약관',
#  None,
#  '내용',
#  None,
#  '청약',
#  '철회',
#  '배송',
#  '책임',
#  '환불',
#  '조건',
#  None,
#  '내용',
#  '이용자',
#  '이해',
#  None,
#  '별도',
#  '연결',
#  '화면',
#  '팝업',
#  '화면',
#  None,
#  '제공',
#  '이용자',
#  '확인',
#  None,
#  None,
#  '전자상거래',
#  None,
#  '소비자보호',
#  None,
#  '법률',
#  '약관',
#  '규제',
#  None,
#  '법률',
#  '전자문서',
#  None,
#  '전자거래',
#  '기본',
#  None,
#  '전자',
#  '금융',
#  '거래',
#  None,
#  '전자서명',
#  None,
#  '정보통신망',
#  '이용',
#  '촉진',
#  None,
#  '정보보호',
#  None,
#  None,
#  '법률',
#  '방문',
#  '판매',
#  None,
#  None,
#  '법률',
#  '소비자보호법',
#  None,
#  '관련',
#  None,
#  None,
#  '배하',
#  '범위',
#  None,
#  '약관',
#  '개정',
#  None,
#  None,
#  '약관',
#  '개정',
#  '경우',
#  '적용',
#  '일자',
#  None,
#  '개정',
#  '사유',
#  '명시',
#  '현행',
#  '약관',
#  '초기',
#  '화면',
#  None,
#  '적용',
#  '일자',
#  '적용',
#  '일자',
#  '전일',
#  '공지',
#  '다만',
#  '이용자',
#  '약관',
#  '내용',
#  '변경',
#  '경우',
#  '최소한',
#  '이상',
#  '사전',
#  '유예',
#  '기간',
#  '공지',
#  None,
#  '경우',
#  None,
#  None,
#  '정전',
#  '내용',
#  '개정',
#  None,
#  '내용',
#  '비교',
#  '이용자',
#  '표시',
#  None,
#  '약관',
#  '개정',
#  '경우',
#  None,
#  '개정',
#  '약관',
#  None,
#  '적용',
#  '일자',
#  '이후',
#  '체결',
#  '계약',
#  '적용',
#  None,
#  '이전',
#  '체결',
#  '계약',
#  '대해',
#  '개정',
#  '전의',
#  '약관',
#  '조항',
#  '그대로',
#  '적용',
#  '다만',
#  '계약',
#  '체결',
#  '이용자',
#  '개정',
#  '약관',
#  '조항',
#  '적용',
#  None,
#  None,
#  None,
#  '개정',
#  '약관',
#  '기간',
#  None,
#  '송신',
#  None,
#  '동의',
#  '경우',
#  '개정',
#  '약관',
#  '조항',
#  '적용',
#  None,
#  '약관',
#  None,
#  '사항',
#  None,
#  '약관',
#  '해석',
#  None,
#  '전자상거래',
#  None,
#  '소비자보호',
#  None,
#  '법률',
#  '약관',
#  '규제',
#  None,
#  None,
#  '법률',
#  '정거',
#  '위원회',
#  None,
#  '전자상거래',
#  None,
#  '소비자보호',
#  '지침',
#  None,
#  '관계',
#  '법령',
#  None,
#  '관례',
#  None,
#  '서비스',
#  '제공',
#  None,
#  '변경',
#  None,
#  '다음',
#  '업무',
#  '수행',
#  '재화',
#  '용역',
#  '대한',
#  '정보',
#  '제공',
#  None,
#  '계약',
#  '체결',
#  '계약',
#  '체결',
#  '재화',
#  '용역',
#  '배송',
#  '기타',
#  None,
#  None,
#  '업무',
#  None,
#  '재화',
#  '용역',
#  '품질',
#  '기술',
#  '사양',
#  '변경',
#  None,
#  '경우',
#  '장차',
#  '체결',
#  '계약',
#  '제공',
#  '재화',
#  '용역',
#  '내용',
#  '변경',
#  None,
#  None,
#  '경우',
#  '변경',
#  '재화',
#  '용역',
#  '내용',
#  None,
#  '일자',
#  '명시',
#  '현재',
#  '재화',
#  '용역',
#  '내용',
#  '게시',
#  None,
#  '즉시',
#  '공지',
#  None,
#  '제공',
#  '이용자',
#  '계약',
#  '체결',
#  '서비스',
#  '내용',
#  '재화',
#  None,
#  '품질',
#  '기술',
#  '사양',
#  '변경',
#  None,
#  '사유',
#  '변경',
#  '경우',
#  None,
#  '사유',
#  '이용자',
#  '통지',
#  '주소',
#  '즉시',
#  '통지',
#  '항의',
#  '경우',
#  None,
#  '이로',
#  '이용자',
#  '손해',
#  '배상',
#  '다만',
#  None,
#  '고의',
#  '과실',
#  None,
#  '입증',
#  '경우',
#  None,
#  '서비스',
#  '중단',
#  '상품',
#  '변심',
#  '반품',
#  '경우',
#  '반송',
#  '고객',
#  '부담',
#  '초기',
#  None,
#  '송료',
#  '포함',
#  '왕복',
#  None,
#  '송료',
#  '해당',
#  '금액',
#  '고객',
#  '부담',
#  None,
#  '컴퓨터',
#  None,
#  '정보통',
#  '설비',
#  '보수',
#  '점검',
#  '교체',
#  None,
#  '고장',
#  '통신',
#  '두절',
#  None,
#  '사유',
#  '발생',
#  '경우',
#  '서비스',
#  '제공',
#  '일시',
#  '중단',
#  None,
#  None,
#  None,
#  '항의',
#  '사유',
#  '서비스',
#  '제공',
#  '일시',
#  '중단',
#  '이용자',
#  None,
#  '자가',
#  '손해',
#  '대하',
#  '배상',
#  None,
#  None,
#  '고의',
#  '과실',
#  None,
#  '입증',
#  '경우',
#  '사업',
#  '종목',
#  '전환',
#  '사업',
#  '포기',
#  '업체',
#  '통합',
#  None,
#  '이유',
#  '서비스',
#  '제공',
#  None,
#  '경우',
#  None,
#  None,
#  None,
#  '방법',
#  '이용자',
#  '통지',
#  '당초',
#  '제시',
#  '조건',
#  '소비자',
#  '보상',
#  '다만',
#  None,
#  '보상',
#  '기준',
#  None,
#  '고지',
#  '경우',
#  '통용',
#  '통화',
#  '가치',
#  '상응',
#  '현물',
#  '현금',
#  '이용자',
#  '지급',
#  None,
#  '회원',
#  '가입',
#  '이용자',
#  None,
#  None,
#  '가입',
#  '양식',
#  '회원정보',
#  '기입',
#  None,
#  None,
#  '약관',
#  '동의',
#  '의사표시',
#  None,
#  '회원',
#  '가입',
#  '신청',
#  None,
#  None,
#  None,
#  '회원',
#  '가입',
#  None,
#  '신청',
#  '이용자',
#  None,
#  '다음',
#  None,
#  '해당',
#  '회원',
#  '등록',
#  '가입',
#  '신청',
#  None,
#  '약관',
#  None,
#  None,
#  '이전',
#  '회원',
#  '자격',
#  None,
#  '경우',
#  '다만',
#  None,
#  None,
#  '회원',
#  '자격',
#  '상실',
#  None,
#  '경과',
#  '자로',
#  None,
#  '회원',
#  None,
#  '가입',
#  '승낙',
#  '경우',
#  '예외',
#  '등록',
#  '내용',
#  '허위',
#  '기재',
#  '누락',
#  '오기',
#  '경우',
#  '기타',
#  '회원',
#  '등록',
#  None,
#  None,
#  '기술',
#  '현저',
#  '지장',
#  '판단',
#  '경우',
#  '회원',
#  '가입',
#  '계약',
#  '성립',
#  '시기',
#  None,
#  '승낙',
#  '회원',
#  '도달',
#  '시점',
#  '회원',
#  None,
#  None,
#  '등록',
#  '사항',
#  '변경',
#  '경우',
#  '기간',
#  '이내',
#  '대하',
#  '회원정보',
#  '수정',
#  None,
#  '방법',
#  None,
#  '변경',
#  '사항',
#  None,
#  '회원',
#  '탈퇴',
#  None,
#  '자격',
#  '상실',
#  None,
#  '회원',
#  '언제',
#  '탈퇴',
#  '요청',
#  None,
#  None,
#  '즉시',
#  '회원',
#  '탈퇴',
#  '처리',
#  '회원',
#  '다음',
#  '호의',
#  '사유',
#  '해당',
#  '경우',
#  None,
#  '회원',
#  '자격',
#  '제한',
#  None,
#  '정지',
#  None,
#  '가입',
#  '신청',
#  None,
#  '허위',
#  '내용',
#  '등록',
#  '경우',
#  '이용',
#  '구입',
#  '재화',
#  None,
#  '대금',
#  '기타',
#  '이용',
#  '관련',
#  '회원',
#  '부담',
#  '채무',
#  '기일',
#  '지급',
#  '경우',
#  '다른',
#  '사람',
#  '이용',
#  None,
#  None,
#  '정보',
#  '도용',
#  None,
#  '전자상거래',
#  '질서',
#  '위협',
#  '경우',
#  '이용',
#  '법령',
#  None,
#  '약관',
#  '금지',
#  '거나',
#  '양속',
#  '행위',
#  '경우',
#  None,
#  '회원',
#  '대한',
#  '통지',
#  None,
#  '회원',
#  '대한',
#  '통지',
#  '경우',
#  '회원',
#  None,
#  '미리',
#  '약정',
#  '지정',
#  '전자우편',
#  '주소',
#  None,
#  None,
#  None,
#  '특정',
#  '다수',
#  '회원',
#  '대한',
#  '통지',
#  '경우',
#  '주일',
#  '이상',
#  '게시판',
#  '게시',
#  None,
#  '개별',
#  '통지',
#  None,
#  '다만',
#  '회원',
#  '본인',
#  '거래',
#  '관련',
#  '영향',
#  '사항',
#  '대하',
#  None,
#  '개별',
#  '통지',
#  None,
#  '구매',
#  '신청',
#  None,
#  '개인정보',
#  '제공',
#  '동의',
#  None,
#  '이용자',
#  None,
#  '다음',
#  None,
#  '방법',
#  '구매',
#  '신청',
#  None,
#  '이용자',
#  '신청',
#  None,
#  '다음',
#  None,
#  '내용',
#  '제공',
#  '재화',
#  None,
#  '검색',
#  None,
#  '선택',
#  '성명',
#  '주소',
#  '전화번호',
#  '전자우편',
#  '주소',
#  '이동전화',
#  '번호',
#  None,
#  '입력',
#  '약관',
#  '내용',
#  '청약',
#  '철회',
#  '제한',
#  '서비스',
#  None,
#  '송료',
#  '설치',
#  None,
#  None,
#  '비용',
#  '부담',
#  '관련',
#  '내용',
#  '대한',
#  '확인',
#  None,
#  '약관',
#  '동의',
#  None,
#  '호의',
#  '사항',
#  '확인',
#  '거나',
#  '거부',
#  '표시',
#  None,
#  '마우스',
#  '클릭',
#  '재화',
#  None,
#  '구매',
#  '신청',
#  None,
#  None,
#  None,
#  '확인',
#  None,
#  '확인',
#  '대한',
#  '동의',
#  '결제',
#  '방법',
#  '선택',
#  None,
#  None,
#  None,
#  '구매',
#  '개인정보',
#  '제공',
#  '필요',
#  '경우',
#  '개인정보',
#  '제공',
#  None,
#  '개인정보',
#  '제공',
#  '자의',
#  '개인정보',
#  '이용',
#  '목정',
#  '제공',
#  '개인정보',
#  '항목',
#  '개인정보',
#  '제공',
#  '자의',
#  '개인정보',
#  '보유',
#  None,
#  '이용기',
#  '구매',
#  '알리',
#  '동의',
#  '동의',
#  '사항',
#  '변경',
#  '경우',
#  None,
#  None,
#  None,
#  '구매',
#  '자의',
#  '개인정보',
#  '취급',
#  None,
#  '업무',
#  '위탁',
#  '경우',
#  '개인정보',
#  '취급',
#  '위탁',
#  None,
#  '개인정보',
#  '취급',
#  '위탁',
#  '업무',
#  '내용',
#  '구매',
#  '알리',
#  '동의',
#  '동의',
#  '사항',
#  '변경',
#  '경우',
#  '다만',
#  '서비스',
#  '제공',
#  None,
#  '계약',
#  '이행',
#  '위해',
#  '구매',
#  '자의',
#  '편의',
#  '증진',
#  '관련',
#  '경우',
#  '정보통신망',
#  '이용',
#  '촉진',
#  None,
#  '정보보호',
#  None,
#  None,
#  '법률',
#  None,
#  '방법',
#  '개인정보',
#  '취급',
#  '방침',
#  '통해',
#  '알림',
#  '고지',
#  '절차',
#  '동의',
#  '절차',
#  '거치',
#  None,
#  '계약',
#  '성립',
#  None,
#  None,
#  '신청',
#  '대하',
#  '다음',
#  None,
#  '해당',
#  '승낙',
#  None,
#  '다만',
#  '미성년',
#  '계약',
#  '체결',
#  '경우',
#  '법정',
#  '대리인',
#  '동의',
#  '얻지',
#  '미성년',
#  '본인',
#  '법정',
#  '대리인',
#  '계약',
#  '취소',
#  None,
#  '애용',
#  '고지',
#  '신청',
#  '내용',
#  '허위',
#  '기재',
#  '누락',
#  ...]

# %%
words2 = [i for i in nouns if len(i) > 1]

# %%
words2
# Out:
# ['목적',
#  '약관',
#  '씨앤피',
#  '물류',
#  '회사',
#  '전자거래',
#  '사업자',
#  '운영',
#  '씨앤피',
#  '물류',
#  '사이버',
#  '이하',
#  '제공',
#  '인터넷',
#  '관련',
#  '서비스',
#  '이하',
#  '서비스',
#  '이용',
#  '사이버',
#  '이용자',
#  '권리',
#  '의무',
#  '책임',
#  '사항',
#  '규정',
#  '목적',
#  '통신',
#  '이용',
#  '전자거래',
#  '대해',
#  '서도',
#  '성질',
#  '약관',
#  '준용',
#  '정의',
#  '이란',
#  '씨앤피',
#  '물류',
#  '회사',
#  '재화',
#  '용역',
#  '이용자',
#  '제공',
#  '컴퓨터',
#  '정보통',
#  '설비',
#  '이용',
#  '재화',
#  '용역',
#  '거래',
#  '설정',
#  '가상',
#  '영업',
#  '사이버',
#  '운영',
#  '사업자',
#  '의미',
#  '사용',
#  '이용자',
#  '접속',
#  '약관',
#  '제공',
#  '서비스',
#  '회원',
#  '비회',
#  '회원',
#  '개인정보',
#  '제공',
#  '회원',
#  '등록',
#  '자로',
#  '계속',
#  '제공',
#  '서비스',
#  '이용',
#  '비회',
#  '회원',
#  '가입',
#  '제공',
#  '서비스',
#  '이용',
#  '관등',
#  '명시',
#  '설명',
#  '개정',
#  '약관',
#  '내용',
#  '상호',
#  '대표자',
#  '성명',
#  '영업소',
#  '소재지',
#  '주소',
#  '소비자',
#  '불만',
#  '처리',
#  '주소',
#  '포함',
#  '전화번호',
#  '전송',
#  '번호',
#  '전자우편',
#  '주소',
#  '사업자',
#  '등록',
#  '번호',
#  '통신',
#  '판매업',
#  '신고',
#  '번호',
#  '개인정보',
#  '관리',
#  '책임',
#  '자등',
#  '이용자',
#  '초기',
#  '서비스',
#  '화면',
#  '전면',
#  '게시',
#  '다만',
#  '약관',
#  '내용',
#  '이용자',
#  '연결',
#  '화면',
#  '이용자',
#  '약관',
#  '동의',
#  '앞서',
#  '약관',
#  '내용',
#  '청약',
#  '철회',
#  '배송',
#  '책임',
#  '환불',
#  '조건',
#  '내용',
#  '이용자',
#  '이해',
#  '별도',
#  '연결',
#  '화면',
#  '팝업',
#  '화면',
#  '제공',
#  '이용자',
#  '확인',
#  '전자상거래',
#  '소비자보호',
#  '법률',
#  '약관',
#  '규제',
#  '법률',
#  '전자문서',
#  '전자거래',
#  '기본',
#  '전자',
#  '금융',
#  '거래',
#  '전자서명',
#  '정보통신망',
#  '이용',
#  '촉진',
#  '정보보호',
#  '법률',
#  '방문',
#  '판매',
#  '법률',
#  '소비자보호법',
#  '관련',
#  '배하',
#  '범위',
#  '약관',
#  '개정',
#  '약관',
#  '개정',
#  '경우',
#  '적용',
#  '일자',
#  '개정',
#  '사유',
#  '명시',
#  '현행',
#  '약관',
#  '초기',
#  '화면',
#  '적용',
#  '일자',
#  '적용',
#  '일자',
#  '전일',
#  '공지',
#  '다만',
#  '이용자',
#  '약관',
#  '내용',
#  '변경',
#  '경우',
#  '최소한',
#  '이상',
#  '사전',
#  '유예',
#  '기간',
#  '공지',
#  '경우',
#  '정전',
#  '내용',
#  '개정',
#  '내용',
#  '비교',
#  '이용자',
#  '표시',
#  '약관',
#  '개정',
#  '경우',
#  '개정',
#  '약관',
#  '적용',
#  '일자',
#  '이후',
#  '체결',
#  '계약',
#  '적용',
#  '이전',
#  '체결',
#  '계약',
#  '대해',
#  '개정',
#  '전의',
#  '약관',
#  '조항',
#  '그대로',
#  '적용',
#  '다만',
#  '계약',
#  '체결',
#  '이용자',
#  '개정',
#  '약관',
#  '조항',
#  '적용',
#  '개정',
#  '약관',
#  '기간',
#  '송신',
#  '동의',
#  '경우',
#  '개정',
#  '약관',
#  '조항',
#  '적용',
#  '약관',
#  '사항',
#  '약관',
#  '해석',
#  '전자상거래',
#  '소비자보호',
#  '법률',
#  '약관',
#  '규제',
#  '법률',
#  '정거',
#  '위원회',
#  '전자상거래',
#  '소비자보호',
#  '지침',
#  '관계',
#  '법령',
#  '관례',
#  '서비스',
#  '제공',
#  '변경',
#  '다음',
#  '업무',
#  '수행',
#  '재화',
#  '용역',
#  '대한',
#  '정보',
#  '제공',
#  '계약',
#  '체결',
#  '계약',
#  '체결',
#  '재화',
#  '용역',
#  '배송',
#  '기타',
#  '업무',
#  '재화',
#  '용역',
#  '품질',
#  '기술',
#  '사양',
#  '변경',
#  '경우',
#  '장차',
#  '체결',
#  '계약',
#  '제공',
#  '재화',
#  '용역',
#  '내용',
#  '변경',
#  '경우',
#  '변경',
#  '재화',
#  '용역',
#  '내용',
#  '일자',
#  '명시',
#  '현재',
#  '재화',
#  '용역',
#  '내용',
#  '게시',
#  '즉시',
#  '공지',
#  '제공',
#  '이용자',
#  '계약',
#  '체결',
#  '서비스',
#  '내용',
#  '재화',
#  '품질',
#  '기술',
#  '사양',
#  '변경',
#  '사유',
#  '변경',
#  '경우',
#  '사유',
#  '이용자',
#  '통지',
#  '주소',
#  '즉시',
#  '통지',
#  '항의',
#  '경우',
#  '이로',
#  '이용자',
#  '손해',
#  '배상',
#  '다만',
#  '고의',
#  '과실',
#  '입증',
#  '경우',
#  '서비스',
#  '중단',
#  '상품',
#  '변심',
#  '반품',
#  '경우',
#  '반송',
#  '고객',
#  '부담',
#  '초기',
#  '송료',
#  '포함',
#  '왕복',
#  '송료',
#  '해당',
#  '금액',
#  '고객',
#  '부담',
#  '컴퓨터',
#  '정보통',
#  '설비',
#  '보수',
#  '점검',
#  '교체',
#  '고장',
#  '통신',
#  '두절',
#  '사유',
#  '발생',
#  '경우',
#  '서비스',
#  '제공',
#  '일시',
#  '중단',
#  '항의',
#  '사유',
#  '서비스',
#  '제공',
#  '일시',
#  '중단',
#  '이용자',
#  '자가',
#  '손해',
#  '대하',
#  '배상',
#  '고의',
#  '과실',
#  '입증',
#  '경우',
#  '사업',
#  '종목',
#  '전환',
#  '사업',
#  '포기',
#  '업체',
#  '통합',
#  '이유',
#  '서비스',
#  '제공',
#  '경우',
#  '방법',
#  '이용자',
#  '통지',
#  '당초',
#  '제시',
#  '조건',
#  '소비자',
#  '보상',
#  '다만',
#  '보상',
#  '기준',
#  '고지',
#  '경우',
#  '통용',
#  '통화',
#  '가치',
#  '상응',
#  '현물',
#  '현금',
#  '이용자',
#  '지급',
#  '회원',
#  '가입',
#  '이용자',
#  '가입',
#  '양식',
#  '회원정보',
#  '기입',
#  '약관',
#  '동의',
#  '의사표시',
#  '회원',
#  '가입',
#  '신청',
#  '회원',
#  '가입',
#  '신청',
#  '이용자',
#  '다음',
#  '해당',
#  '회원',
#  '등록',
#  '가입',
#  '신청',
#  '약관',
#  '이전',
#  '회원',
#  '자격',
#  '경우',
#  '다만',
#  '회원',
#  '자격',
#  '상실',
#  '경과',
#  '자로',
#  '회원',
#  '가입',
#  '승낙',
#  '경우',
#  '예외',
#  '등록',
#  '내용',
#  '허위',
#  '기재',
#  '누락',
#  '오기',
#  '경우',
#  '기타',
#  '회원',
#  '등록',
#  '기술',
#  '현저',
#  '지장',
#  '판단',
#  '경우',
#  '회원',
#  '가입',
#  '계약',
#  '성립',
#  '시기',
#  '승낙',
#  '회원',
#  '도달',
#  '시점',
#  '회원',
#  '등록',
#  '사항',
#  '변경',
#  '경우',
#  '기간',
#  '이내',
#  '대하',
#  '회원정보',
#  '수정',
#  '방법',
#  '변경',
#  '사항',
#  '회원',
#  '탈퇴',
#  '자격',
#  '상실',
#  '회원',
#  '언제',
#  '탈퇴',
#  '요청',
#  '즉시',
#  '회원',
#  '탈퇴',
#  '처리',
#  '회원',
#  '다음',
#  '호의',
#  '사유',
#  '해당',
#  '경우',
#  '회원',
#  '자격',
#  '제한',
#  '정지',
#  '가입',
#  '신청',
#  '허위',
#  '내용',
#  '등록',
#  '경우',
#  '이용',
#  '구입',
#  '재화',
#  '대금',
#  '기타',
#  '이용',
#  '관련',
#  '회원',
#  '부담',
#  '채무',
#  '기일',
#  '지급',
#  '경우',
#  '다른',
#  '사람',
#  '이용',
#  '정보',
#  '도용',
#  '전자상거래',
#  '질서',
#  '위협',
#  '경우',
#  '이용',
#  '법령',
#  '약관',
#  '금지',
#  '거나',
#  '양속',
#  '행위',
#  '경우',
#  '회원',
#  '대한',
#  '통지',
#  '회원',
#  '대한',
#  '통지',
#  '경우',
#  '회원',
#  '미리',
#  '약정',
#  '지정',
#  '전자우편',
#  '주소',
#  '특정',
#  '다수',
#  '회원',
#  '대한',
#  '통지',
#  '경우',
#  '주일',
#  '이상',
#  '게시판',
#  '게시',
#  '개별',
#  '통지',
#  '다만',
#  '회원',
#  '본인',
#  '거래',
#  '관련',
#  '영향',
#  '사항',
#  '대하',
#  '개별',
#  '통지',
#  '구매',
#  '신청',
#  '개인정보',
#  '제공',
#  '동의',
#  '이용자',
#  '다음',
#  '방법',
#  '구매',
#  '신청',
#  '이용자',
#  '신청',
#  '다음',
#  '내용',
#  '제공',
#  '재화',
#  '검색',
#  '선택',
#  '성명',
#  '주소',
#  '전화번호',
#  '전자우편',
#  '주소',
#  '이동전화',
#  '번호',
#  '입력',
#  '약관',
#  '내용',
#  '청약',
#  '철회',
#  '제한',
#  '서비스',
#  '송료',
#  '설치',
#  '비용',
#  '부담',
#  '관련',
#  '내용',
#  '대한',
#  '확인',
#  '약관',
#  '동의',
#  '호의',
#  '사항',
#  '확인',
#  '거나',
#  '거부',
#  '표시',
#  '마우스',
#  '클릭',
#  '재화',
#  '구매',
#  '신청',
#  '확인',
#  '확인',
#  '대한',
#  '동의',
#  '결제',
#  '방법',
#  '선택',
#  '구매',
#  '개인정보',
#  '제공',
#  '필요',
#  '경우',
#  '개인정보',
#  '제공',
#  '개인정보',
#  '제공',
#  '자의',
#  '개인정보',
#  '이용',
#  '목정',
#  '제공',
#  '개인정보',
#  '항목',
#  '개인정보',
#  '제공',
#  '자의',
#  '개인정보',
#  '보유',
#  '이용기',
#  '구매',
#  '알리',
#  '동의',
#  '동의',
#  '사항',
#  '변경',
#  '경우',
#  '구매',
#  '자의',
#  '개인정보',
#  '취급',
#  '업무',
#  '위탁',
#  '경우',
#  '개인정보',
#  '취급',
#  '위탁',
#  '개인정보',
#  '취급',
#  '위탁',
#  '업무',
#  '내용',
#  '구매',
#  '알리',
#  '동의',
#  '동의',
#  '사항',
#  '변경',
#  '경우',
#  '다만',
#  '서비스',
#  '제공',
#  '계약',
#  '이행',
#  '위해',
#  '구매',
#  '자의',
#  '편의',
#  '증진',
#  '관련',
#  '경우',
#  '정보통신망',
#  '이용',
#  '촉진',
#  '정보보호',
#  '법률',
#  '방법',
#  '개인정보',
#  '취급',
#  '방침',
#  '통해',
#  '알림',
#  '고지',
#  '절차',
#  '동의',
#  '절차',
#  '거치',
#  '계약',
#  '성립',
#  '신청',
#  '대하',
#  '다음',
#  '해당',
#  '승낙',
#  '다만',
#  '미성년',
#  '계약',
#  '체결',
#  '경우',
#  '법정',
#  '대리인',
#  '동의',
#  '얻지',
#  '미성년',
#  '본인',
#  '법정',
#  '대리인',
#  '계약',
#  '취소',
#  '애용',
#  '고지',
#  '신청',
#  '내용',
#  '허위',
#  '기재',
#  '누락',
#  '오기',
#  '경우',
#  '미성년',
#  '담배',
#  '주류',
#  '청소년',
#  '보호',
#  '금지',
#  '재화',
#  '용역',
#  '구매',
#  '경우',
#  '기타',
#  '신청',
#  '승낙',
#  '기술',
#  '현저',
#  '지장',
#  '판단',
#  '경우',
#  '승낙',
#  '항의',
#  '확인',
#  '통지',
#  '형태',
#  '이용자',
#  '도달',
#  '시점',
#  '계약',
#  '성립',
#  '승낙',
#  '의사표시',
#  '이용자',
#  '구매',
#  '신청',
#  '대한',
#  '확인',
#  '판매',
#  '가능',
#  '여부',
#  '신청',
#  '정정',
#  '취소',
#  '정보',
#  '포함',
#  '지급',
#  '방법',
#  '구매',
#  '재화',
#  '용역',
#  '대한',
#  '금지',
#  '방법',
#  '다음',
#  '호의',
#  '방법',
#  '가용',
#  '방법',
#  '이용자',
#  '지급',
#  '방법',
#  '대하',
#  '재화',
#  '대금',
#  '명목',
#  '수수료',
#  '추가',
#  '징수',
#  '뱅킹',
#  '인터넷',
#  '뱅킹',
#  '메일',
#  '뱅킹',
#  '각종',
#  '계좌',
#  '이체',
#  '선불카드',
#  '직불카드',
#  '신용카드',
#  '각종',
#  '카드',
#  '결제',
#  '온라인',
#  '통장',
#  '입금',
#  '전자화폐',
#  '결제',
#  '수령',
#  '대금',
#  '지급',
#  '마일리지',
#  '지급',
#  '포인트',
#  '결제',
#  '계약',
#  '인정',
#  '상품권',
#  '결제',
#  '기타',
#  '전자',
#  '지급',
#  '방법',
#  '대금',
#  '지급',
#  '확인',
#  '통지',
#  '구매',
#  '신청',
#  '변경',
#  '취소',
#  '이용자',
#  '신청',
#  '경우',
#  '이용자',
#  '확인',
#  '통지',
#  '확인',
#  '통지',
#  '이용자',
#  '의사표시',
#  '일치',
#  '경우',
#  '확인',
#  '통지',
#  '즉시',
#  '구매',
#  '신청',
#  '변경',
#  '취소',
#  '요청',
#  '송전',
#  '이용자',
#  '요청',
#  '경우',
#  '지체',
#  '요청',
#  '처리',
#  '다만',
#  '대금',
#  '지불',
#  '경우',
#  '청약',
#  '철회',
#  '규정',
#  '재화',
#  '공급',
#  '이용자',
#  '재화',
#  '공급',
#  '시기',
#  '별도',
#  '공지',
#  '이상',
#  '이용자',
#  '청약',
#  '이내',
#  '재화',
#  '배송',
#  '주문',
#  '제작',
#  '포장',
#  '기타',
#  '조치',
#  '취합니',
#  '다만',
#  '재화',
#  '대금',
#  '전부',
#  '일부',
#  '경우',
#  '대금',
#  '전부',
#  '일부',
#  '영업일',
#  '이내',
#  '조치',
#  '취합니',
#  '이용자',
#  '재화',
#  '공급',
#  '절차',
#  '진행',
#  '사항',
#  '확인',
#  '조치',
#  '이용자',
#  '구매',
#  '재화',
#  '대해',
#  '배송',
#  '수단',
#  '수단',
#  '배송',
#  '비용',
#  '부담',
#  '수단',
#  '배송',
#  '기간',
#  '명시',
#  '만약',
#  '약정',
#  '배송',
#  '기간',
#  '초과',
#  '경우',
#  '그로',
#  '이용자',
#  '손해',
#  '배상',
#  '다만',
#  '고의',
#  '과실',
#  '입증',
#  '경우',
#  '환급',
#  '이용자',
#  '구매',
#  '신청',
#  '재화',
#  '품절',
#  '사유',
#  '인도',
#  '제공',
#  '지체',
#  '사유',
#  '이용자',
#  '통지',
#  '사전',
#  '재화',
#  '대금',
#  ...]

# %%
from collections import Counter

# %%
cnt = Counter(words)

# %%
# 워드클라우드 라이브러리
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.25.1)
# Requirement already satisfied: pillow in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (10.0.0)
# Requirement already satisfied: matplotlib in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\eungok\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
# worldcloud로 시각화
wc = WordCloud(
    font_path='malgun',
    width=800,
    height=800,
    scale=2.0,
    max_font_size=300,
    max_words=200
)

# %%
gen = wc.generate_from_frequencies(cnt)
plt.figure(figsize=(14,8))
plt.axis('off')
plt.imshow(gen)

# %%
# 특정한 이미지 모양대로 워드클라우드를 생성
img = Image.open('./pngwing.png')
# 이미지파일을 행렬식으로 변환
img_array = np.array(img)
img_array
# Out:
# array([[[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        ...,
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]]], dtype=uint8)

# %%
wc2 = WordCloud(
    font_path='malgun',
    width=800,
    height=800,
    scale=2.0,
    max_font_size=350,
    max_words=200,
    mask= img_array
)

# %%
gen2 = wc2.generate_from_frequencies(cnt)
plt.axis('off')
plt.imshow(gen2)

# %%
import sys

# %%
sys.path
# Out:
# ['c:\\apps\\jquery\\pandas',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310',
#  '',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib',
#  'c:\\Users\\eungok\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\Pythonwin']
