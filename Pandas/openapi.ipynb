8b\x9c\xea\xb5\xb0\xea\xb5\xac><\xec\x9a\xa9\xeb\x8f\x84\xec\xa7\x80\xec\x97\xad>\xec\xa0\x9c2\xec\xa2\x85\xec\x9d\xbc\xeb\xb0\x98\xec\xa3\xbc\xea\xb1\xb0</\xec\x9a\xa9\xeb\x8f\x84\xec\xa7\x80\xec\x97\xad><\xec\x9b\x94>8</\xec\x9b\x94><\xec\x9c\xa0\xed\x98\x95>\xec\xa7\x91\xed\x95\xa9</\xec\x9c\xa0\xed\x98\x95><\xec\x9d\xbc>14</\xec\x9d\xbc><\xec\xa4\x91\xea\xb0\x9c\xec\x82\xac\xec\x86\x8c\xec\x9e\xac\xec\xa7\x80>\xec\x84\x9c\xec\x9a\xb8 \xec\xa2\x85\xeb\xa1\x9c\xea\xb5\xac, \xec\x84\x9c\xec\x9a\xb8 \xec\xa4\x91\xea\xb5\xac</\xec\xa4\x91\xea\xb0\x9c\xec\x82\xac\xec\x86\x8c\xec\x9e\xac\xec\xa7\x80><\xec\xa7\x80\xeb\xb2\x88>7*</\xec\xa7\x80\xeb\xb2\x88><\xec\xa7\x80\xec\x97\xad\xec\xbd\x94\xeb\x93\x9c>11110</\xec\xa7\x80\xec\x97\xad\xec\xbd\x94\xeb ...

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
import xmltodict

# %%
# xml 데이터를 dict 형태로 변환
data = xmltodict.parse(response.content)

# %%
import pprint
pprint.pprint(data['response']['body']['items']['item'])
dict_data=data['response']['body']['items']['item']
# Out:
# [{'거래금액': '32,000',
#   '거래유형': '중개거래',
#   '건물면적': '55.53',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1991',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청운동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '집합',
#   '일': '14',
#   '중개사소재지': '서울 종로구, 서울 중구',
#   '지번': '7*',
#   '지역코드': '11110',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '80,000',
#   '거래유형': '중개거래',
#   '건물면적': '82.27',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '1991',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청운동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '집합',
#   '일': '14',
#   '중개사소재지': '서울 종로구, 서울 중구',
#   '지번': '7*',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '360,000',
#   '거래유형': '직거래',
#   '건물면적': '302.88',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1972',
#   '년': '2023',
#   '대지면적': '198.3',
#   '법정동': '통인동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '20',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '125,000',
#   '거래유형': '중개거래',
#   '건물면적': '108.69',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1974',
#   '년': '2023',
#   '대지면적': '76',
#   '법정동': '누하동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '1',
#   '중개사소재지': '서울 중구',
#   '지번': '9*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '10,000',
#   '거래유형': '중개거래',
#   '건물면적': '20.18',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '2004',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '내수동',
#   '시군구': '종로구',
#   '용도지역': '준주거',
#   '월': '8',
#   '유형': '집합',
#   '일': '26',
#   '중개사소재지': '서울 종로구',
#   '지번': '7*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '60,000',
#   '거래유형': '중개거래',
#   '건물면적': '59.04',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '2005',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '신문로1가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '4',
#   '중개사소재지': '서울 종로구',
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '66,000',
#   '거래유형': '직거래',
#   '건물면적': '18.98',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '64,000',
#   '거래유형': '직거래',
#   '건물면적': '18.31',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '59,000',
#   '거래유형': '직거래',
#   '건물면적': '16.87',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '113,000',
#   '거래유형': '직거래',
#   '건물면적': '28.07',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '65,000',
#   '거래유형': '직거래',
#   '건물면적': '18.6',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '62,000',
#   '거래유형': '직거래',
#   '건물면적': '17.86',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '57,000',
#   '거래유형': '직거래',
#   '건물면적': '16.37',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '109,000',
#   '거래유형': '직거래',
#   '건물면적': '27.08',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '231,000',
#   '거래유형': '직거래',
#   '건물면적': '122.6',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '2',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '338,000',
#   '거래유형': '직거래',
#   '건물면적': '161.65',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '2',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '1,340,000',
#   '거래유형': '직거래',
#   '건물면적': '641.1',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '2',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '149,300',
#   '거래유형': '직거래',
#   '건물면적': '101.97',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '239,400',
#   '거래유형': '직거래',
#   '건물면적': '163.51',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,339,800',
#   '거래유형': '직거래',
#   '건물면적': '1119.28',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '3',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,200,400',
#   '거래유형': '직거래',
#   '건물면적': '1052.6',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '4',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,200,400',
#   '거래유형': '직거래',
#   '건물면적': '1052.6',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '5',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '6',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '7',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '8',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '9',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '11',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '13',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '14',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '15',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '16',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '17',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,233,300',
#   '거래유형': '직거래',
#   '건물면적': '1068.2',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '18',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '19',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,232,800',
#   '거래유형': '직거래',
#   '건물면적': '1068.14',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '20',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,228,900',
#   '거래유형': '직거래',
#   '건물면적': '1066.17',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '21',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,228,900',
#   '거래유형': '직거래',
#   '건물면적': '1066.17',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '22',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,228,900',
#   '거래유형': '직거래',
#   '건물면적': '1066.11',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '23',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '2,228,900',
#   '거래유형': '직거래',
#   '건물면적': '1066.11',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '24',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '56,000',
#   '거래유형': '직거래',
#   '건물면적': '67.76',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '234,000',
#   '거래유형': '직거래',
#   '건물면적': '280.11',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '114,000',
#   '거래유형': '직거래',
#   '건물면적': '136.39',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '290,000',
#   '거래유형': '직거래',
#   '건물면적': '346.47',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '135,000',
#   '거래유형': '직거래',
#   '건물면적': '160.56',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '74,000',
#   '거래유형': '직거래',
#   '건물면적': '88.32',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '12,600',
#   '거래유형': '직거래',
#   '건물면적': '35.84',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '34,000',
#   '거래유형': '직거래',
#   '건물면적': '97.69',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '12,600',
#   '거래유형': '직거래',
#   '건물면적': '35.84',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '34,000',
#   '거래유형': '직거래',
#   '건물면적': '97.69',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '12,600',
#   '거래유형': '직거래',
#   '건물면적': '35.84',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '34,000',
#   '거래유형': '직거래',
#   '건물면적': '97.69',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '12,600',
#   '거래유형': '직거래',
#   '건물면적': '35.84',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '30,200',
#   '거래유형': '직거래',
#   '건물면적': '87.65',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '219,000',
#   '거래유형': '직거래',
#   '건물면적': '78.66',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '648,000',
#   '거래유형': '직거래',
#   '건물면적': '232.65',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '44,000',
#   '거래유형': '직거래',
#   '건물면적': '12.04',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '40,000',
#   '거래유형': '직거래',
#   '건물면적': '11.38',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '44,000',
#   '거래유형': '직거래',
#   '건물면적': '12.64',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '53,000',
#   '거래유형': '직거래',
#   '건물면적': '15.33',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '62,000',
#   '거래유형': '직거래',
#   '건물면적': '17.84',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '41,000',
#   '거래유형': '직거래',
#   '건물면적': '11.8',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '42,000',
#   '거래유형': '직거래',
#   '건물면적': '12.05',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '43,000',
#   '거래유형': '직거래',
#   '건물면적': '12.31',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '41,000',
#   '거래유형': '직거래',
#   '건물면적': '11.72',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '45,000',
#   '거래유형': '직거래',
#   '건물면적': '12.26',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '448,000',
#   '거래유형': '직거래',
#   '건물면적': '135.37',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '2015',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '청진동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': None,
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '12,000',
#   '거래유형': '직거래',
#   '건물면적': '10.52',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '1992',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '인사동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '25',
#   '중개사소재지': None,
#   '지번': '4*',
#   '지역코드': '11110',
#   '층': '1',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '240,000',
#   '거래유형': '중개거래',
#   '건물면적': '152.85',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1991',
#   '년': '2023',
#   '대지면적': '88.4',
#   '법정동': '삼청동',
#   '시군구': '종로구',
#   '용도지역': '제1종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '1',
#   '중개사소재지': '서울 강남구, 서울 종로구',
#   '지번': '1*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '300,000',
#   '거래유형': '중개거래',
#   '건물면적': '91.07',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '1992',
#   '년': '2023',
#   '대지면적': '129.6',
#   '법정동': '화동',
#   '시군구': '종로구',
#   '용도지역': '제1종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '30',
#   '중개사소재지': '서울 마포구',
#   '지번': '2*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '1,400,000',
#   '거래유형': '중개거래',
#   '건물면적': '1113.6',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '1999',
#   '년': '2023',
#   '대지면적': '746',
#   '법정동': '가회동',
#   '시군구': '종로구',
#   '용도지역': '제1종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '30',
#   '중개사소재지': '서울 종로구',
#   '지번': '*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '80,000',
#   '거래유형': '중개거래',
#   '건물면적': '16.53',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '1960',
#   '년': '2023',
#   '대지면적': '29.8',
#   '법정동': '장사동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '일반',
#   '일': '21',
#   '중개사소재지': '서울 종로구',
#   '지번': '4*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '31,855',
#   '거래유형': '직거래',
#   '건물면적': '10.68',
#   '건물주용도': '제1종근린생활',
#   '건축년도': '1958',
#   '년': '2023',
#   '대지면적': '9.16',
#   '법정동': '종로5가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '일반',
#   '일': '14',
#   '중개사소재지': None,
#   '지번': '4**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '192,000',
#   '거래유형': '중개거래',
#   '건물면적': '105.78',
#   '건물주용도': '제1종근린생활',
#   '년': '2023',
#   '대지면적': '63.5',
#   '법정동': '종로5가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '일반',
#   '일': '25',
#   '중개사소재지': '경기 양평군',
#   '지번': '3**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '22,500',
#   '거래유형': '중개거래',
#   '건물면적': '10.88',
#   '건물주용도': '판매',
#   '건축년도': '1973',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '종로6가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': '경기 남양주시, 서울 종로구',
#   '지번': '2**',
#   '지역코드': '11110',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '19,000',
#   '거래유형': '중개거래',
#   '건물면적': '8.66',
#   '건물주용도': '판매',
#   '건축년도': '1973',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '종로6가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': '경기 남양주시, 서울 종로구',
#   '지번': '2**',
#   '지역코드': '11110',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '22,500',
#   '거래유형': '중개거래',
#   '건물면적': '10.88',
#   '건물주용도': '판매',
#   '건축년도': '1973',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '종로6가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': '경기 남양주시, 서울 종로구',
#   '지번': '2**',
#   '지역코드': '11110',
#   '층': '10',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '19,000',
#   '거래유형': '중개거래',
#   '건물면적': '8.66',
#   '건물주용도': '판매',
#   '건축년도': '1973',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '종로6가',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '16',
#   '중개사소재지': '경기 남양주시, 서울 종로구',
#   '지번': '2**',
#   '지역코드': '11110',
#   '층': '12',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '740,000',
#   '거래유형': '직거래',
#   '건물면적': '382.22',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1980',
#   '년': '2023',
#   '대지면적': '377.3',
#   '법정동': '동숭동',
#   '시군구': '종로구',
#   '용도지역': '제3종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '22',
#   '중개사소재지': None,
#   '지번': '*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '220,000',
#   '거래유형': '중개거래',
#   '건물면적': '232.12',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '2010',
#   '년': '2023',
#   '대지면적': '112.4',
#   '법정동': '동숭동',
#   '시군구': '종로구',
#   '용도지역': '제1종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '25',
#   '중개사소재지': '서울 강남구',
#   '지번': '5*',
#   '지역코드': '11110',
#   '해제사유발생일': '23.09.14',
#   '해제여부': 'O'},
#  {'거래금액': '220,000',
#   '거래유형': '중개거래',
#   '건물면적': '232.12',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '2010',
#   '년': '2023',
#   '대지면적': '112.4',
#   '법정동': '동숭동',
#   '시군구': '종로구',
#   '용도지역': '제1종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '25',
#   '중개사소재지': '서울 강남구',
#   '지번': '5*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '85,536',
#   '거래유형': '중개거래',
#   '건물면적': '29.18',
#   '건물주용도': '판매',
#   '년': '2023',
#   '대지면적': '58.93',
#   '법정동': '혜화동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '14',
#   '중개사소재지': '서울 종로구',
#   '지번': '7*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '76,000',
#   '거래유형': '직거래',
#   '건물면적': '29.18',
#   '건물주용도': '제1종근린생활',
#   '년': '2023',
#   '대지면적': '58.93',
#   '법정동': '혜화동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '일반',
#   '일': '23',
#   '중개사소재지': None,
#   '지번': '7*',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '56,500',
#   '거래유형': '중개거래',
#   '건물면적': '34.03',
#   '건물주용도': '판매',
#   '건축년도': '2017',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '교북동',
#   '시군구': '종로구',
#   '용도지역': '일반상업',
#   '월': '8',
#   '유형': '집합',
#   '일': '25',
#   '중개사소재지': '서울 종로구',
#   '지번': '1**',
#   '지역코드': '11110',
#   '층': '41',
#   '해제사유발생일': None,
#   '해제여부': None},
#  {'거래금액': '95,000',
#   '거래유형': '중개거래',
#   '건물면적': '136.59',
#   '건물주용도': '제2종근린생활',
#   '건축년도': '1997',
#   '년': '2023',
#   '대지면적': None,
#   '법정동': '평창동',
#   '시군구': '종로구',
#   '용도지역': '제2종일반주거',
#   '월': '8',
#   '유형': '집합',
#   '일': '8',
#   '중개사소재지': '서울 종로구',
#   '지번': '5**',
#   '지역코드': '11110',
#   '해제사유발생일': None,
#   '해제여부': None}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict_data)

# %%
df.to_csv("./sample_data.csv", index=False)

# %%
import openapi

# %%
url ="http://apis.data.go.kr/1160100/service/GetFnCoBasiInfoService/getFnCoOutl"
params = {
    'serviceKey' : 'dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw==',
    'pageNo' : '1',
    'numOfRows' : '100',
    'resultType' : 'xml'
}
openapi.api_data(url,params)
# Out:
#    actnAudpnNm audtRptOpnnCtt     basDt        bzno corpRegMrktDcd  \
# 0       삼일회계법인           적정의견  20200408  2028116825              P
# 1         None           None  20200408  1048126728              E
# 2         None           None  20200408  1168119031              P
# 3         None           None  20200408  1168111757              P
# 4         None           None  20200408  2118134851              E
# ..         ...            ...       ...         ...            ...
# 95        None           None  20200408  1208122480              E
# 96        None           None  20200408  1208124038              E
# 97        None           None  20200408  2158133572              E
# 98        None           None  20200408  2148185311              E
# 99        None           None  20200408         107              E
#
#    corpRegMrktDcdNm           crno empeAvgCnwkTermCtt  \
# 0                유가  1101110002959                 10
# 1                기타  1101110002975                8.9
# 2                유가  1101110003155            11년 1개월
# 3                유가  1101110003204               17.8
# 4                기타  1101110003444               None
# ..              ...            ...                ...
# 95               기타  1101110132087               None
# 96               기타  1101110133572             5년 0개월
# 97               기타  1101110135099               None
# 98               기타  1101110135148               None
# 99               기타  1101110135164               None
#
#                                    fncoAdr fncoEmpeAvgSlryAmt  ...  \
# 0                    서울특별시 중구  청계천로 86 24층           68000000  ...
# 1             서울특별시 서초구 서초대로74길 14 삼성물산(주)           89000000  ...
# 2   서울특별시 영등포구  여의대로 56 한화증권빌딩 한화투자증권 주식회사           93000000  ...
# 3                        서울특별시 영등포구 63로 50           83000000  ...
# 4                      서울특별시 강남구 논현동 105-7                  0  ...
# ..                                     ...                ...  ...
# 95                     서울특별시 강남구 삼성동 71-15                  0  ...
# 96       서울특별시 강남구 테헤란로 427 (삼성동, 현대스위스타워)           33000000  ...
# 97                      서울특별시 송파구 가락동 79번지                  0  ...
# 98                서울특별시 강남구 테헤란로 512 (대치동)                  0  ...
# 99                   서울특별시 영등포구 양평동 1가 190                  0  ...
#
#    fncoXchgLstgDt fncoZpcd fssCorpChgDtm fssCorpUnqNo  isinCd isinCdNm  \
# 0        76/06/24    04541    2020/01/13     00160588  000880   000880
# 1            None    06620    2017/06/30     00126229  000830   000830
# 2        86/11/25    07325    2020/01/13     00148610  003530   003530
# 3        10/03/17    07345    2020/01/13     00113058  088350   088350
# 4            None   135714    2017/06/30     00115852  002950   002950
# ..            ...      ...           ...          ...     ...      ...
# 95           None   135090    2017/06/30     00129448    None     None
# 96           None    06159    2017/06/30     00100416    None     None
# 97       96/11/19   138160    2017/06/30     00190817    None     None
# 98           None    06179    2020/02/27     00149196    None     None
# 99           None   150101    2017/06/30     00163497    None     None
#
#    mntrFcnFncoCd mntrFcnFncoCdNm sicCd  sicNm
# 0           None            None  None  20494
# 1           None            None  None    467
# 2           None            None  None  66121
# 3           None            None  None  65110
# 4           None            None  None  41221
# ..           ...             ...   ...    ...
# 95          None            None  None  64131
# 96          None            None  None  64132
# 97          None            None  None  64131
# 98          None            None  None  64132
# 99          None            None  None  64131
#
# [100 rows x 36 columns]
